# %% [markdown]
# # Clase 8: Introducción a Manejo de Datos Tabulares con Pandas
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**

# %% [markdown]
# ### Objetivos de la clase
#
# - Introducir los datos estructurados de forma tabular.
# - Comprender los aspectos introductorios de `pandas`: `Series` y `DataFrames`.
# - Indexado y operaciones básicas en `DataFrames`.
# - Filtrados y queries.

# %% [markdown]
# # Motivación
#
# Primero, se presentará el dataset con el cuál estaremos trabajando durante la clase y luego, vendrán unas preguntas interesantes al respecto.

# %% [markdown]
# ### Índices para una Vida Mejor
#
# Para explicar `pandas`, analizaremos datos de la OECD, en particular de los índices para una Vida Mejor:
#
#
# <img src="./resources/oecd.png" alt="OECD Better life index"/>
#
#
# http://www.oecdbetterlifeindex.org/
#
# https://stats.oecd.org/Index.aspx?DataSetCode=BLI
#
# Son 11 temas considerados como esenciales para el bienestar de la población. Cada crierio contiene uno o mas indicadores
#
# | Tema | Indicador (Inglés) | Indicador (Español) | Unidad | Descripción |
# |---|---|---|---|---|
# | Vivienda 🏠 | Dwellings without basic facilities | Vivienda con Instalaciones Básicas | Porcentaje | Porcentaje de personas con inodoros de agua corriente dentro del hogar, año disponible más reciente |
# |  | Housing expenditure | Gastos en Vivienda | Porcentaje | Proporción de costos de vivienda en el ingreso neto ajustado de las familias, año disponible más reciente |
# |  | Rooms per person | Habitaciones por Persona | Ratio | Número promedio de habitaciones compartidas por persona en una vivienda, año disponible más reciente |
# | Ingresos 💰 | Household net adjusted disposable income | Ingreso Familiar Disponible | US Dollar | Cantidad promedio de dinero que una familia gana al año, después de impuestos, año disponible más reciente |
# |  | Household net wealth | Patrimonio Neto Familiar | US Dollar | Valor total promedio de los activos financieros de una familia (ahorros, acciones) menos sus pasivos (créditos), año disponible más reciente |
# | Empleo ⚙️ | Labour market insecurity | Seguridad en el Empleo | Porcentaje | Pérdida esperada de ingresos cuando alguien queda desempleado, año disponible más reciente |
# |  | Employment rate | Tasa de Empleo | Porcentaje | Porcentaje de personas, de 15 a 64 años de edad, actualmente con empleo remunerado, año disponible más reciente |
# |  | Long-term unemployment rate | Tasa de Empleo a Largo Plazo | Porcentaje | Porcentaje de personas, de 15 a 64 años de edad, que no trabajan pero que han buscado empleo activamente durante más de un año, año disponible más reciente |
# |  | Personal earnings | Ingresos Personales | US Dollar | Ingresos anuales promedio por empleado de tiempo completo, año disponible más reciente |
# | Comunidad 🧑‍🤝‍🧑   | Quality of support network  | Calidad del Apoyo Social | Porcentaje | Porcentaje de personas con amigos o parientes en quienes confiar en caso de necesidad |
# | Educación 📚 | Educational attainment | Nivel de Educación | Porcentaje | Porcentaje de personas, de 25 a 64 años de edad, graduadas por lo menos de educación media superior, año disponible más reciente |
# |  | Student skills | Competencias de estudiantes en matemáticas, lectura y ciencias | Puntaje promedio | Desempeño promedio de estudiantes de 15 años de edad, según PISA (Programa para la Evaluación Internacional de Estudiantes) |
# |  | Years in education  | Nivel de educación | Años | Duración promedio de la educación formal en la que un niño de cinco años de edad puede esperar matricularse durante su vida |
# | Medio Ambiente 🌳 | Air pollution | Contaminación del Aire | Microgramos por metro cúbico | Concentración promedio de partículas (PM2.5) en ciudades con poblaciones mayores de 100,000 personas, medida en microgramos por metro cúbico, año disponible más reciente |
# |  | Water quality | Calidad del Agua | Porcentaje | Porcentaje de personas que informan estar satisfechas con la calidad del agua local |
# | Compromiso Cívico 🗳️  | Stakeholder engagement for developing regulations | Participación de los interesados en la elaboración de regulaciones | Puntaje promedio | Nivel de transparencia gubernamental al preparar las regulaciones, año disponible más reciente |
# |  | Voter turnout | Participación electoral | Porcentaje | Porcentaje de votantes registrados que votaron durante las elecciones recientes, año disponible más reciente |
# | Salud ⚕️ | Life expectancy | Esperanza de vida | Años | Número promedio de años que una persona puede esperar vivir, año disponible más reciente |
# |  | Self-reported health | Salud según informan las personas | Porcentaje | Porcentaje de personas que informan que su salud es «buena o muy buena», año disponible más reciente |
# | Satisfacción ✨ | Life satisfaction | Satisfacción ante la vida | Puntaje promedio | Autoevaluación promedio de satisfacción ante la vida, en una escala de 0 a 10 |
# | Seguridad 🌃 | Feeling safe walking alone at night | Sentimiento de seguridad al caminar solos por la noche | Porcentaje | Porcentaje de personas que reportan sentirse seguras al caminar solas por la noche  |
# |  | Homicide rate | Tasa de homicidios | Ratio | Número promedio de homicidios reportados por 100,000 personas, año disponible más reciente |
# | Balance Vida Trabajo 🧘 | Employees working very long hours | Empleados que trabajan muchas horas | Porcentaje | Porcentaje de empleados que trabajan más de cincuenta horas a la semana en promedio, año disponible más reciente |
# |  | Time devoted to leisure and personal care | Tiempo destinado al ocio y el cuidado personal | Horas | Número promedio de minutos al día dedicados al ocio y el cuidado personal, incluidos el sueño y la alimentación |

# %% [markdown]
# ---
#
# **Hasta el momento, todos los datos con los que hemos trabajado:**

# %% [markdown]
# ### 1. Los hemos ingresado a mano
#
# En este caso, tendríamos que copiar y pegar los datos en formato arreglo de forma manual.
#
# Por ejemplo, las 10 primeras filas del dataset de la OECD de las columnas:
#
# - Air pollution
# - Dwellings without basic facilities
# - Educational attainment
# - Employees working very long hours
# - Employment rate

# %%
import numpy as np

datos = np.array(
    [
        [5.0, np.nan, 81.0, 12.84, 73.0],
        [16.0, 0.9, 85.0, 6.59, 72.0],
        [15.0, 1.9, 77.0, 4.7, 63.33],
        [10.0, 6.7, 49.0, 7.01, 61.0],
        [7.0, 0.2, 91.33, 3.67, 73.33],
        [16.0, 9.4, 65.0, 9.32, 62.67],
        [10.0, 23.9, 54.0, 26.01, 67.0],
        [20.0, 0.7, 93.67, 5.5, 73.67],
        [9.0, 0.5, 81.0, 2.32, 74.0],
        [8.0, 7.0, 88.67, 2.44, 74.0],
    ]
)

datos
# Out:
# array([[ 5.  ,   nan, 81.  , 12.84, 73.  ],
#        [16.  ,  0.9 , 85.  ,  6.59, 72.  ],
#        [15.  ,  1.9 , 77.  ,  4.7 , 63.33],
#        [10.  ,  6.7 , 49.  ,  7.01, 61.  ],
#        [ 7.  ,  0.2 , 91.33,  3.67, 73.33],
#        [16.  ,  9.4 , 65.  ,  9.32, 62.67],
#        [10.  , 23.9 , 54.  , 26.01, 67.  ],
#        [20.  ,  0.7 , 93.67,  5.5 , 73.67],
#        [ 9.  ,  0.5 , 81.  ,  2.32, 74.  ],
#        [ 8.  ,  7.  , 88.67,  2.44, 74.  ]])

# %% [markdown]
# > **Pregunta ❓**: Entonces, ¿Cómo en numpy podría leer una planilla Excel? ¿Y un archivo json? ¿O un CSV? ¿ O una base de datos?

# %% [markdown]
# ### 2. Solo hemos usado números
#
# > **Pregunta ❓**: ¿Cómo puedo operar strings en numpy?
#
# En este caso, me gustaría agregar una nueva columna a los datos: el oaís que describen los valores:

# %%
pais = np.array([
    "Australia",
    "Austria",
    "Belgium",
    "Brazil",
    "Canada",
    "Chile",
    "Colombia",
    "Czech Republic",
    "Denmark",
    "Estonia",
])

# %% [markdown]
# Pero recuerden que para que numpy funcione eficientemente, los arreglos deben ser homogeneos, es decir, del mismo tipo.
#
# > **Pregunta: ❓** ¿Qué consecuencias podría traer el agregar esta nueva columna a los datos?

# %%
# Out:
# array([['Australia', 'Austria', 'Belgium', 'Brazil', 'Canada', 'Chile',
#         'Colombia', 'Czech Republic', 'Denmark', 'Estonia']], dtype='<U14')

# %%
nuevos_datos = np.concatenate([pais[:, np.newaxis], datos], axis=1)
nuevos_datos
# Out:
# array([['Australia', '5.0', 'nan', '81.0', '12.84', '73.0'],
#        ['Austria', '16.0', '0.9', '85.0', '6.59', '72.0'],
#        ['Belgium', '15.0', '1.9', '77.0', '4.7', '63.33'],
#        ['Brazil', '10.0', '6.7', '49.0', '7.01', '61.0'],
#        ['Canada', '7.0', '0.2', '91.33', '3.67', '73.33'],
#        ['Chile', '16.0', '9.4', '65.0', '9.32', '62.67'],
#        ['Colombia', '10.0', '23.9', '54.0', '26.01', '67.0'],
#        ['Czech Republic', '20.0', '0.7', '93.67', '5.5', '73.67'],
#        ['Denmark', '9.0', '0.5', '81.0', '2.32', '74.0'],
#        ['Estonia', '8.0', '7.0', '88.67', '2.44', '74.0']], dtype='<U32')

# %%
nuevos_datos.mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 nuevos_datos.mean(axis=1)
#
# File ~/miniconda3/envs/mds7202/lib/python3.9/site-packages/numpy/core/_methods.py:180, in _mean(a, axis, dtype, out, keepdims, where)
#     177         dtype = mu.dtype('f4')
#     178         is_float16_result = True
# --> 180 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     181 if isinstance(ret, mu.ndarray):
#     182     ret = um.true_divide(
#     183             ret, rcount, out=ret, casting='unsafe', subok=False)
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> None

# %% [markdown]
# ### 3. Trabajamos solo con índices para obtener datos.

# %% [markdown]
# > **Pregunta ❓** : ¿Y si mis filas o columnas tuvieran nombre (un string), cómo las podría agregar a numpy?

# %%
columnas = [
    "Country",
    "Air pollution",
    "Dwellings without basic facilities",
    "Educational attainment",
    "Employees working very long hours",
    "Employment rate",
]

# %% [markdown]
# Las recién listadas son un solo un par de limitaciones de `numpy` a la hora de manejar datos.
#
# Como podemos ver, lamentablemente `numpy` carece de funcionalidades más avanzadas pero necesarias para ejecutar adecuada y eficientemente tareas de data science.
#
# Aquí es donde entra en juego `pandas`.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Pandas 🐼

# %% [markdown]
# `Pandas` (derivado de _panel data_)  una librería para python utilizada para manejar datos tabulares.
#
# <div align='center'>
# <img src="./resources/dataframe.png" alt="DataFrames" style="width: 800px;"/>
# </div>
#
#
# Está diseñada para proveer herramientas que faciliten la exploración, limpieza y procesamiento de los datos. Su enfoque es *simplicidad y eficiencia*. Es, al igual que las librerías anteriores, *open-source*.
#
#
# La base de pandas son los `DataFrames`.

# %% [markdown]
# Como convención, `Pandas` se importa de la siguiente manera:

# %%
import pandas as pd

# %% [markdown]
# ### Entrada / Salida (IO)

# %% [markdown]
# La lectura de datos en `pandas` es muy sencilla: `pandas` es compatible con muchos tipos de archivos y fuentes de datos de forma nativa:
#
# - `CSV`
# - `Excel`
# - `SQL`
# - `Json`
# - ...
#
# Los datos almacenados en estas fuentes pueden ser importados a `DataFrames` a través de las funcioes `read_*`
#
# De la misma forma, es capaz de guardar los DataFrames en el formato que deseen usando las funciones `to_*`
#
# <div align='center'>
#
# <img src="./resources/pandas_io.png" alt="DataFrames" style="width: 800px;"/>
# </div>
#
# Toda la información acerca de que puede o no leer la encuentran en la siguiente referencia: https://pandas.pydata.org/docs/user_guide/io.html

# %% [markdown]
# ### Importar el Dataset
#
# A continuacion, importaremos el dataset a un `DataFrame`. Noten la gran compatiblidad de `Jupyter` con los DataFrames (DF).
#
# Cada DataFrame tiene **indices (Primera columna ) y columnas (primera fila)**. Comunmente se ocupan:
#
# - En las columnas se ocupan `strings` que identifican el nombre de la variable.
# - Enteros que identifican el número de la observación en las filas.
#
# Sin embargo, las filas también pueden ser identificadas por strings como las columnas por enteros

# %%
# para abrir archivos excel y visualizar hay que instalar esta dependencia extra
# !pip install pandas openpyxl matplotlib plotly statsmodels
# Out:
# Requirement already satisfied: pandas in /home/pablo/miniconda3/lib/python3.9/site-packages (1.4.1)
# Requirement already satisfied: openpyxl in /home/pablo/miniconda3/lib/python3.9/site-packages (3.0.9)
# Requirement already satisfied: matplotlib in /home/pablo/miniconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: plotly in /home/pablo/miniconda3/lib/python3.9/site-packages (5.6.0)
# Requirement already satisfied: statsmodels in /home/pablo/miniconda3/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/pablo/miniconda3/lib/python3.9/site-packages (from pandas) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/pablo/miniconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/pablo/miniconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: et-xmlfile in /home/pablo/miniconda3/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/pablo/miniconda3/lib/python3.9/site-packages (from matplotlib) (9.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/pablo/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/pablo/miniconda3/lib/python3.9/site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pablo/miniconda3/lib/python3.9/site-packages (from matplotlib) (4.32.0)
# Requirement already satisfied: packaging>=20.0 in /home/pablo/miniconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/pablo/miniconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/pablo/miniconda3/lib/python3.9/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /home/pablo/miniconda3/lib/python3.9/site-packages (from plotly) (1.16.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/pablo/miniconda3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: scipy>=1.3 in /home/pablo/miniconda3/lib/python3.9/site-packages (from statsmodels) (1.8.0)

# %%
import pandas as pd

# utilidad para mostrar todas las columnas
pd.set_option("display.max_columns", None)


df = pd.read_excel("./resources/dataset.xlsx", header=1, index_col=0)
df
# Out:
#                  Dwellings without basic facilities  Housing expenditure  \
# Country
# Australia                                       NaN                 20.0
# Austria                                         0.9                 21.0
# Belgium                                         1.9                 21.0
# Canada                                          0.2                 22.0
# Chile                                           9.4                 18.0
# Colombia                                       23.9                 17.0
# Czech Republic                                  0.7                 24.0
# Denmark                                         0.5                 23.0
# Estonia                                         7.0                 17.0
# Finland                                         0.5                 23.0
# France                                          0.5                 21.0
# Germany                                         0.2                 20.0
# Greece                                          0.5                 23.0
# Hungary                                         4.7                 19.0
# Iceland                                         0.0                 24.0
# Ireland                                         1.0                 20.0
# Israel                                          NaN                  NaN
# Italy                                           0.7                 23.0
# Japan                                           6.4                 22.0
# Korea                                           2.5                 15.0
# Latvia                                         13.9                 23.0
# Lithuania                                      13.6                 19.0
# Luxembourg                                      0.5                 21.0
# Mexico                                         25.5                 20.0
# Netherlands                                     0.1                 19.0
# New Zealand                                     NaN                 26.0
# Norway                                          0.0                 17.0
# Poland                                          3.0                 22.0
# Portugal                                        1.0                 21.0
# Slovak Republic                                 1.2                 23.0
# Slovenia                                        0.4                 18.0
# Spain                                           0.1                 21.0
# Sweden                                          0.0                 19.0
# Switzerland                                     0.1                 22.0
# Turkey                                          8.0                 20.0
# United Kingdom                                  0.3                 26.0
# United States                                   0.1                 19.0
# OECD - Total                                    4.4                 20.0
# Brazil                                          6.7                  NaN
# Russia                                         14.8                 18.0
# South Africa                                   37.0                 18.0
#
#                  Rooms per person  Household net adjusted disposable income  \
# Country
# Australia                     NaN                                   32759.0
# Austria                       1.6                                   33541.0
# Belgium                       2.2                                   30364.0
# Canada                        2.6                                   30854.0
# Chile                         1.2                                       NaN
# Colombia                      1.2                                       NaN
# Czech Republic                1.4                                   21453.0
# Denmark                       1.9                                   29606.0
# Estonia                       1.6                                   19697.0
# Finland                       1.9                                   29943.0
# France                        1.8                                   31304.0
# Germany                       1.8                                   34294.0
# Greece                        1.2                                   17700.0
# Hungary                       1.2                                       NaN
# Iceland                       1.6                                       NaN
# Ireland                       2.1                                   25310.0
# Israel                        1.2                                       NaN
# Italy                         1.4                                   26588.0
# Japan                         1.9                                   29798.0
# Korea                         1.5                                   21882.0
# Latvia                        1.2                                   16275.0
# Lithuania                     1.5                                   21660.0
# Luxembourg                    1.9                                   39264.0
# Mexico                        1.0                                       NaN
# Netherlands                   1.9                                   29333.0
# New Zealand                   2.4                                       NaN
# Norway                        2.1                                   35725.0
# Poland                        1.1                                   19814.0
# Portugal                      1.7                                   21203.0
# Slovak Republic               1.1                                   20474.0
# Slovenia                      1.5                                   20820.0
# Spain                         1.9                                   23999.0
# Sweden                        1.7                                   31287.0
# Switzerland                   1.9                                   37466.0
# Turkey                        1.0                                       NaN
# United Kingdom                1.9                                   28715.0
# United States                 2.4                                   45284.0
# OECD - Total                  1.8                                   33604.0
# Brazil                        NaN                                       NaN
# Russia                        0.9                                       NaN
# South Africa                  NaN                                       NaN
#
#                  Household net wealth  Labour market insecurity  \
# Country
# Australia                    427064.0                       5.4
# Austria                      308325.0                       3.5
# Belgium                      386006.0                       3.7
# Canada                       423849.0                       6.0
# Chile                        100967.0                       8.7
# Colombia                          NaN                       NaN
# Czech Republic                    NaN                       3.1
# Denmark                      118637.0                       4.2
# Estonia                      159373.0                       3.8
# Finland                      200827.0                       3.9
# France                       280653.0                       7.6
# Germany                      259667.0                       2.7
# Greece                       150134.0                      29.8
# Hungary                      104458.0                       4.7
# Iceland                           NaN                       0.7
# Ireland                      217130.0                       7.8
# Israel                            NaN                       4.2
# Italy                        279889.0                      12.3
# Japan                        305878.0                       1.4
# Korea                        285980.0                       2.6
# Latvia                        70160.0                       9.6
# Lithuania                         NaN                       NaN
# Luxembourg                   769053.0                       1.7
# Mexico                            NaN                       5.5
# Netherlands                  157824.0                       4.8
# New Zealand                  388514.0                       4.7
# Norway                       228936.0                       NaN
# Poland                       210991.0                       5.7
# Portugal                     232666.0                      10.0
# Slovak Republic              119696.0                       9.9
# Slovenia                     203044.0                       5.8
# Spain                        373548.0                      23.1
# Sweden                            NaN                       3.2
# Switzerland                       NaN                       NaN
# Turkey                            NaN                      12.5
# United Kingdom               548392.0                       4.5
# United States                632100.0                       7.7
# OECD - Total                 408376.0                       7.0
# Brazil                            NaN                       NaN
# Russia                            NaN                       NaN
# South Africa                      NaN                       NaN
#
#                  Employment rate  Long-term unemployment rate  \
# Country
# Australia                     73                         1.31
# Austria                       72                         1.84
# Belgium                       63                         3.54
# Canada                        73                         0.77
# Chile                         63                          NaN
# Colombia                      67                         0.79
# Czech Republic                74                         1.04
# Denmark                       74                         1.31
# Estonia                       74                         1.92
# Finland                       70                         2.13
# France                        65                         4.00
# Germany                       75                         1.57
# Greece                        53                        15.65
# Hungary                       68                         1.72
# Iceland                       86                         0.26
# Ireland                       67                         3.23
# Israel                        69                         0.49
# Italy                         58                         6.59
# Japan                         75                         1.03
# Korea                         67                         0.05
# Latvia                        70                         3.35
# Lithuania                     70                         2.69
# Luxembourg                    66                         2.35
# Mexico                        61                         0.07
# Netherlands                   76                         1.97
# New Zealand                   77                         0.74
# Norway                        74                         0.66
# Poland                        66                         1.52
# Portugal                      68                         4.43
# Slovak Republic               66                         4.78
# Slovenia                      69                         3.17
# Spain                         62                         7.66
# Sweden                        77                         1.12
# Switzerland                   80                         1.82
# Turkey                        52                         2.39
# United Kingdom                75                         1.13
# United States                 70                         0.66
# OECD - Total                  68                         1.78
# Brazil                        61                          NaN
# Russia                        70                         1.59
# South Africa                  43                        16.46
#
#                  Personal earnings  Quality of support network  \
# Country
# Australia                  49126.0                          95
# Austria                    50349.0                          92
# Belgium                    49675.0                          91
# Canada                     47622.0                          93
# Chile                      25879.0                          85
# Colombia                       NaN                          89
# Czech Republic             25372.0                          91
# Denmark                    51466.0                          95
# Estonia                    24336.0                          92
# Finland                    42964.0                          95
# Mexico                      16             68
# Netherlands                 14             93
# New Zealand                  5             89
# Norway                       5             98
# Poland                      22             82
# Portugal                    10             86
# Slovak Republic             21             85
# Slovenia                    16             90
# Spain                       11             72
# Sweden                       6             96
# Switzerland                 15             95
# Turkey                      20             65
# United Kingdom              11             84
# United States               10             83
# OECD - Total                14             81
# Brazil                      10             73
# Russia                      15             55
# South Africa                22             67
#
#                  Stakeholder engagement for developing regulations  \
# Country
# Australia                                                      2.7
# Austria                                                        1.3
# Belgium                                                        2.0
# Canada                                                         2.9
# Chile                                                          1.3
# Colombia                                                       1.4
# Czech Republic                                                 1.6
# Denmark                                                        2.0
# Estonia                                                        2.7
# Finland                                                        2.2
# France                                                         2.1
# Germany                                                        1.8
# Greece                                                         1.8
# Hungary                                                        1.2
# Iceland                                                        2.1
# Ireland                                                        1.3
# Israel                                                         2.5
# Italy                                                          2.5
# Japan                                                          1.4
# Korea                                                          2.9
# Latvia                                                         2.2
# Lithuania                                                      2.4
# Luxembourg                                                     1.7
# Mexico                                                         3.2
# Netherlands                                                    2.6
# New Zealand                                                    2.5
# Norway                                                         2.2
# Poland                                                         2.6
# Portugal                                                       1.5
# Slovak Republic                                                3.0
# Slovenia                                                       2.5
# Spain                                                          1.8
# Sweden                                                         2.0
# Switzerland                                                    2.3
# Turkey                                                         1.5
# United Kingdom                                                 3.1
# United States                                                  3.1
# OECD - Total                                                   2.4
# Brazil                                                         2.2
# Russia                                                         NaN
# South Africa                                                   NaN
#
#                  Voter turnout  Life expectancy  Self-reported health  \
# Country
# Australia                   91             82.5                  85.0
# Austria                     80             81.7                  70.0
# Belgium                     89             81.5                  74.0
# Canada                      68             81.9                  88.0
# Chile                       47             79.9                  57.0
# Colombia                    53             76.2                   NaN
# Czech Republic              61             79.1                  60.0
# Denmark                     86             80.9                  71.0
# Estonia                     64             77.8                  53.0
# Finland                     67             81.5                  70.0
# France                      75             82.4                  66.0
# Germany                     76             81.1                  65.0
# Greece                      64             81.5                  74.0
# Hungary                     70             76.2                  60.0
# Iceland                     79             82.3                  76.0
# Ireland                     65             81.8                  83.0
# Israel                      72             82.5                  84.0
# Italy                       73             83.3                  71.0
# Japan                       53             84.1                  36.0
# Korea                       77             82.4                  33.0
# Latvia                      59             74.7                  47.0
# Lithuania                   51             74.8                  43.0
# Luxembourg                  91             82.8                  69.0
# Mexico                      63             75.4                  66.0
# Netherlands                 82             81.6                  76.0
# New Zealand                 80             81.7                  88.0
# Norway                      78             82.5                  77.0
# Poland                      55             78.0                  58.0
# Portugal                    56             81.2                  48.0
# Slovak Republic             60             77.3                  66.0
# Slovenia                    53             81.3                  64.0
# Spain                       70             83.4                  72.0
# Sweden                      86             82.4                  75.0
# Switzerland                 49             83.7                  78.0
# Turkey                      86             78.0                  69.0
# United Kingdom              69             81.2                  69.0
# United States               65             78.6                  88.0
# OECD - Total                68             80.2                  69.0
# Brazil                      79             74.8                   NaN
# Russia                      68             71.8                  43.0
# South Africa                73             57.5                   NaN
#
#                  Life satisfaction  Feeling safe walking alone at night  \
# Country
# Australia                      7.3                                 63.5
# Austria                        7.1                                 80.6
# Belgium                        6.9                                 70.1
# Canada                         7.4                                 82.2
# Chile                          6.5                                 47.9
# Colombia                       6.3                                 44.4
# Czech Republic                 6.7                                 72.3
# Denmark                        7.6                                 83.5
# Estonia                        5.7                                 69.0
# Finland                        7.6                                 85.1
# France                         6.5                                 70.5
# Germany                        7.0                                 72.5
# Greece                         5.4                                 60.0
# Hungary                        5.6                                 56.3
# Iceland                        7.5                                 86.0
# Ireland                        7.0                                 75.9
# Israel                         7.2                                 69.8
# Italy                          6.0                                 58.4
# Japan                          5.9                                 72.5
# Korea                          5.9                                 66.6
# Latvia                         5.9                                 62.4
# Lithuania                      5.9                                 55.9
# Luxembourg                     6.9                                 75.8
# Mexico                         6.5                                 41.8
# Netherlands                    7.4                                 82.0
# New Zealand                    7.3                                 65.7
# Norway                         7.6                                 90.1
# Poland                         6.1                                 67.3
# Portugal                       5.4                                 73.4
# Slovak Republic                6.2                                 63.5
# Slovenia                       5.9                                 86.1
# Spain                          6.3                                 82.1
# Sweden                         7.3                                 75.6
# Switzerland                    7.5                                 85.3
# Turkey                         5.5                                 59.8
# United Kingdom                 6.8                                 77.7
# United States                  6.9                                 73.9
# OECD - Total                   6.5                                 68.4
# Brazil                         6.4                                 35.6
# Russia                         5.8                                 52.8
# South Africa                   4.7                                 36.1
#
#                  Homicide rate  Employees working very long hours  \
# Country
# Australia                  1.1                              13.04
# Austria                    0.5                               6.66
# Belgium                    1.0                               4.75
# Canada                     1.3                               3.69
# Chile                      4.2                               9.72
# Colombia                  24.5                              26.56
# Czech Republic             0.5                               5.65
# Denmark                    0.6                               2.34
# Estonia                    3.1                               2.42
# Finland                    1.3                               3.81
# France                     0.5                               7.67
# Germany                    0.5                               4.26
# Greece                     0.8                               6.42
# Hungary                    1.0                               3.03
# Iceland                    0.5                              15.06
# Ireland                    0.7                               5.25
# Israel                     1.8                              15.45
# Italy                      0.6                               4.11
# Japan                      0.2                                NaN
# Korea                      1.0                                NaN
# Latvia                     4.8                               1.27
# Lithuania                  3.4                               0.54
# Luxembourg                 0.6                               3.82
# Mexico                    18.1                              28.70
# Netherlands                0.6                               0.42
# New Zealand                1.3                              15.11
# Norway                     0.4                               2.93
# Poland                     0.7                               5.95
# Portugal                   1.0                               8.27
# Slovak Republic            0.8                               4.14
# Slovenia                   0.6                               4.39
# Spain                      0.6                               4.01
# Sweden                     0.9                               1.07
# Switzerland                0.6                               0.37
# Turkey                     1.4                              32.64
# United Kingdom             0.2                              12.15
# United States              5.5                              11.09
# OECD - Total               3.7                              11.01
# Brazil                    26.7                               7.13
# Russia                     9.6                               0.14
# South Africa              13.7                              18.12
#
#                  Time devoted to leisure and personal care
# Country
# Australia                                            14.35
# Austria                                              14.55
# Belgium                                              15.70
# Canada                                               14.56
# Chile                                                  NaN
# Colombia                                               NaN
# Czech Republic                                         NaN
# Denmark                                              15.87
# Estonia                                              14.90
# Finland                                              15.17
# France                                               16.36
# Germany                                              15.62
# Greece                                                 NaN
# Hungary                                                NaN
# Iceland                                                NaN
# Ireland                                                NaN
# Israel                                                 NaN
# Italy                                                16.47
# Japan                                                  NaN
# Korea                                                14.70
# Latvia                                               13.83
# Lithuania                                              NaN
# Luxembourg                                             NaN
# Mexico                                                 NaN
# Netherlands                                            NaN
# New Zealand                                          14.87
# Norway                                               15.56
# Poland                                               14.42
# Portugal                                               NaN
# Slovak Republic                                        NaN
# Slovenia                                             14.75
# Spain                                                15.93
# Sweden                                               15.18
# Switzerland                                            NaN
# Turkey                                               14.79
# United Kingdom                                       14.92
# United States                                        14.44
# OECD - Total                                         14.98
# Brazil                                                 NaN
# Russia                                                 NaN
# South Africa                                         14.92

# %% [markdown]
# ---
#
# ## 2.- Lo Básico
#
# A continuación veremos los atributos y métodos básicos de un DataFrame.

# %% [markdown]
# ### Atributos
#
# #### Columnas
#
# Podemos ver los nombres de las columnas de nuestro `DataFrame` a través de `df.columns`

# %%
df.columns
# Out:
# Index(['Dwellings without basic facilities', 'Housing expenditure',
#        'Rooms per person', 'Household net adjusted disposable income',
#        'Household net wealth', 'Labour market insecurity', 'Employment rate',
#        'Long-term unemployment rate', 'Personal earnings',
#        'Quality of support network', 'Educational attainment',
#        'Student skills', 'Years in education', 'Air pollution',
#        'Water quality', 'Stakeholder engagement for developing regulations',
#        'Voter turnout', 'Life expectancy', 'Self-reported health',
#        'Life satisfaction', 'Feeling safe walking alone at night',
#        'Homicide rate', 'Employees working very long hours',
#        'Time devoted to leisure and personal care'],
#       dtype='object')

# %% [markdown]
# #### Índices

# %% [markdown]
# Podemos ver los indices de las filas de nuestro `DataFrame` a través de `df.index`

# %%
df.index
# Out:
# Index(['Australia', 'Austria', 'Belgium', 'Canada', 'Chile', 'Colombia',
#        'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany',
#        'Greece', 'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Mexico', 'Netherlands',
#        'New Zealand', 'Norway', 'Poland', 'Portugal', 'Slovak Republic',
#        'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Turkey',
#        'United Kingdom', 'United States', 'OECD - Total', 'Brazil', 'Russia',
#        'South Africa'],
#       dtype='object', name='Country')

# %% [markdown]
# #### Largo (cántidad de filas)

# %%
len(df)
# Out:
# 41

# %% [markdown]
# #### Shape

# %%
df.shape
# Out:
# (41, 24)

# %% [markdown]
# ### Información General del Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, Australia to South Africa
# Data columns (total 24 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Dwellings without basic facilities                 38 non-null     float64
#  1   Housing expenditure                                39 non-null     float64
#  2   Rooms per person                                   38 non-null     float64
#  3   Household net adjusted disposable income           30 non-null     float64
#  4   Household net wealth                               29 non-null     float64
#  5   Labour market insecurity                           34 non-null     float64
#  6   Employment rate                                    41 non-null     int64
#  7   Long-term unemployment rate                        39 non-null     float64
#  8   Personal earnings                                  36 non-null     float64
#  9   Quality of support network                         41 non-null     int64
#  10  Educational attainment                             40 non-null     float64
#  11  Student skills                                     40 non-null     float64
#  12  Years in education                                 40 non-null     float64
#  13  Air pollution                                      41 non-null     int64
#  14  Water quality                                      41 non-null     int64
#  15  Stakeholder engagement for developing regulations  39 non-null     float64
#  16  Voter turnout                                      41 non-null     int64
#  17  Life expectancy                                    41 non-null     float64
#  18  Self-reported health                               38 non-null     float64
#  19  Life satisfaction                                  41 non-null     float64
#  20  Feeling safe walking alone at night                41 non-null     float64
#  21  Homicide rate                                      41 non-null     float64
#  22  Employees working very long hours                  39 non-null     float64
#  23  Time devoted to leisure and personal care          23 non-null     float64
# dtypes: float64(19), int64(5)
# memory usage: 8.0+ KB

# %% [markdown]
# ### Selección de Algunos Elementos

# %%
df
# Out:
#                  Dwellings without basic facilities  Housing expenditure  \
# Country
# Australia                                       NaN                 20.0
# Austria                                         0.9                 21.0
# Belgium                                         1.9                 21.0
# Canada                                          0.2                 22.0
# Chile                                           9.4                 18.0
# Colombia                                       23.9                 17.0
# Czech Republic                                  0.7                 24.0
# Denmark                                         0.5                 23.0
# Estonia                                         7.0                 17.0
# Finland                                         0.5                 23.0
# France                                          0.5                 21.0
# Germany                                         0.2                 20.0
# Greece                                          0.5                 23.0
# Hungary                                         4.7                 19.0
# Iceland                                         0.0                 24.0
# Ireland                                         1.0                 20.0
# Israel                                          NaN                  NaN
# Italy                                           0.7                 23.0
# Japan                                           6.4                 22.0
# Korea                                           2.5                 15.0
# Latvia                                         13.9                 23.0
# Lithuania                                      13.6                 19.0
# Luxembourg                                      0.5                 21.0
# Mexico                                         25.5                 20.0
# Netherlands                                     0.1                 19.0
# New Zealand                                     NaN                 26.0
# Norway                                          0.0                 17.0
# Poland                                          3.0                 22.0
# Portugal                                        1.0                 21.0
# Slovak Republic                                 1.2                 23.0
# Slovenia                                        0.4                 18.0
# Spain                                           0.1                 21.0
# Sweden                                          0.0                 19.0
# Switzerland                                     0.1                 22.0
# Turkey                                          8.0                 20.0
# United Kingdom                                  0.3                 26.0
# United States                                   0.1                 19.0
# OECD - Total                                    4.4                 20.0
# Brazil                                          6.7                  NaN
# Russia                                         14.8                 18.0
# South Africa                                   37.0                 18.0
#
#                  Rooms per person  Household net adjusted disposable income  \
# Country
# Australia                     NaN                                   32759.0
# Austria                       1.6                                   33541.0
# Belgium                       2.2                                   30364.0
# Canada                        2.6                                   30854.0
# Chile                         1.2                                       NaN
# Colombia                      1.2                                       NaN
# Czech Republic                1.4                                   21453.0
# Denmark                       1.9                                   29606.0
# Estonia                       1.6                                   19697.0
# Finland                       1.9                                   29943.0
# France                        1.8                                   31304.0
# Germany                       1.8                                   34294.0
# Greece                        1.2                                   17700.0
# Hungary                       1.2                                       NaN
# Iceland                       1.6                                       NaN
# Ireland                       2.1                                   25310.0
# Israel                        1.2                                       NaN
# Italy                         1.4                                   26588.0
# Japan                         1.9                                   29798.0
# Korea                         1.5                                   21882.0
# Latvia                        1.2                                   16275.0
# Lithuania                     1.5                                   21660.0
# Luxembourg                    1.9                                   39264.0
# Mexico                        1.0                                       NaN
# Netherlands                   1.9                                   29333.0
# New Zealand                   2.4                                       NaN
# Norway                        2.1                                   35725.0
# Poland                        1.1                                   19814.0
# Portugal                      1.7                                   21203.0
# Slovak Republic               1.1                                   20474.0
# Slovenia                      1.5                                   20820.0
# Spain                         1.9                                   23999.0
# Sweden                        1.7                                   31287.0
# Switzerland                   1.9                                   37466.0
# Turkey                        1.0                                       NaN
# United Kingdom                1.9                                   28715.0
# United States                 2.4                                   45284.0
# OECD - Total                  1.8                                   33604.0
# Brazil                        NaN                                       NaN
# Russia                        0.9                                       NaN
# South Africa                  NaN                                       NaN
#
#                  Household net wealth  Labour market insecurity  \
# Country
# Australia                    427064.0                       5.4
# Austria                      308325.0                       3.5
# Belgium                      386006.0                       3.7
# Canada                       423849.0                       6.0
# Chile                        100967.0                       8.7
# Colombia                          NaN                       NaN
# Czech Republic                    NaN                       3.1
# Denmark                      118637.0                       4.2
# Estonia                      159373.0                       3.8
# Finland                      200827.0                       3.9
# France                       280653.0                       7.6
# Germany                      259667.0                       2.7
# Greece                       150134.0                      29.8
# Hungary                      104458.0                       4.7
# Iceland                           NaN                       0.7
# Ireland                      217130.0                       7.8
# Israel                            NaN                       4.2
# Italy                        279889.0                      12.3
# Japan                        305878.0                       1.4
# Korea                        285980.0                       2.6
# Latvia                        70160.0                       9.6
# Lithuania                         NaN                       NaN
# Luxembourg                   769053.0                       1.7
# Mexico                            NaN                       5.5
# Netherlands                  157824.0                       4.8
# New Zealand                  388514.0                       4.7
# Norway                       228936.0                       NaN
# Poland                       210991.0                       5.7
# Portugal                     232666.0                      10.0
# Slovak Republic              119696.0                       9.9
# Slovenia                     203044.0                       5.8
# Spain                        373548.0                      23.1
# Sweden                            NaN                       3.2
# Switzerland                       NaN                       NaN
# Turkey                            NaN                      12.5
# United Kingdom               548392.0                       4.5
# United States                632100.0                       7.7
# OECD - Total                 408376.0                       7.0
# Brazil                            NaN                       NaN
# Russia                            NaN                       NaN
# South Africa                      NaN                       NaN
#
#                  Employment rate  Long-term unemployment rate  \
# Country
# Australia                     73                         1.31
# Austria                       72                         1.84
# Belgium                       63                         3.54
# Canada                        73                         0.77
# Chile                         63                          NaN
# Colombia                      67                         0.79
# Czech Republic                74                         1.04
# Denmark                       74                         1.31
# Estonia                       74                         1.92
# Finland                       70                         2.13
# France                        65                         4.00
# Germany                       75                         1.57
# Greece                        53                        15.65
# Hungary                       68                         1.72
# Iceland                       86                         0.26
# Ireland                       67                         3.23
# Israel                        69                         0.49
# Italy                         58                         6.59
# Japan                         75                         1.03
# Korea                         67                         0.05
# Latvia                        70                         3.35
# Lithuania                     70                         2.69
# Luxembourg                    66                         2.35
# Mexico                        61                         0.07
# Netherlands                   76                         1.97
# New Zealand                   77                         0.74
# Norway                        74                         0.66
# Poland                        66                         1.52
# Portugal                      68                         4.43
# Slovak Republic               66                         4.78
# Slovenia                      69                         3.17
# Spain                         62                         7.66
# Sweden                        77                         1.12
# Switzerland                   80                         1.82
# Turkey                        52                         2.39
# United Kingdom                75                         1.13
# United States                 70                         0.66
# Belgium                     15             84
# Canada                       7             91
# Chile                       16             71
# Colombia                    10             75
# Czech Republic              20             87
# Denmark                      9             95
# Estonia                      8             84
# Finland                      6             95
# France                      13             81
# Germany                     14             91
# Greece                      18             69
# Hungary                     19             77
# Iceland                      3             99
# Ireland                      7             85
# Israel                      21             67
# Italy                       18             71
# Japan                       14             87
# Korea                       28             76
# Latvia                      11             79
# Lithuania                   14             81
# Luxembourg                  12             84
# Mexico                      16             68
# Netherlands                 14             93
# New Zealand                  5             89
# Norway                       5             98
# Poland                      22             82
# Portugal                    10             86
# Slovak Republic             21             85
# Slovenia                    16             90
# Spain                       11             72
# Sweden                       6             96
# Switzerland                 15             95
# Turkey                      20             65
# United Kingdom              11             84
# United States               10             83
# OECD - Total                14             81
# Brazil                      10             73
# Russia                      15             55
# South Africa                22             67
#
#                  Stakeholder engagement for developing regulations  \
# Country
# Australia                                                      2.7
# Austria                                                        1.3
# Belgium                                                        2.0
# Canada                                                         2.9
# Chile                                                          1.3
# Colombia                                                       1.4
# Czech Republic                                                 1.6
# Denmark                                                        2.0
# Estonia                                                        2.7
# Finland                                                        2.2
# France                                                         2.1
# Germany                                                        1.8
# Greece                                                         1.8
# Hungary                                                        1.2
# Iceland                                                        2.1
# Ireland                                                        1.3
# Israel                                                         2.5
# Italy                                                          2.5
# Japan                                                          1.4
# Korea                                                          2.9
# Latvia                                                         2.2
# Lithuania                                                      2.4
# Luxembourg                                                     1.7
# Mexico                                                         3.2
# Netherlands                                                    2.6
# New Zealand                                                    2.5
# Norway                                                         2.2
# Poland                                                         2.6
# Portugal                                                       1.5
# Slovak Republic                                                3.0
# Slovenia                                                       2.5
# Spain                                                          1.8
# Sweden                                                         2.0
# Switzerland                                                    2.3
# Turkey                                                         1.5
# United Kingdom                                                 3.1
# United States                                                  3.1
# OECD - Total                                                   2.4
# Brazil                                                         2.2
# Russia                                                         NaN
# South Africa                                                   NaN
#
#                  Voter turnout  Life expectancy  Self-reported health  \
# Country
# Australia                   91             82.5                  85.0
# Austria                     80             81.7                  70.0
# Belgium                     89             81.5                  74.0
# Canada                      68             81.9                  88.0
# Chile                       47             79.9                  57.0
# Colombia                    53             76.2                   NaN
# Czech Republic              61             79.1                  60.0
# Denmark                     86             80.9                  71.0
# Estonia                     64             77.8                  53.0
# Finland                     67             81.5                  70.0
# France                      75             82.4                  66.0
# Germany                     76             81.1                  65.0
# Greece                      64             81.5                  74.0
# Hungary                     70             76.2                  60.0
# Iceland                     79             82.3                  76.0
# Ireland                     65             81.8                  83.0
# Israel                      72             82.5                  84.0
# Italy                       73             83.3                  71.0
# Japan                       53             84.1                  36.0
# Korea                       77             82.4                  33.0
# Latvia                      59             74.7                  47.0
# Lithuania                   51             74.8                  43.0
# Luxembourg                  91             82.8                  69.0
# Mexico                      63             75.4                  66.0
# Netherlands                 82             81.6                  76.0
# New Zealand                 80             81.7                  88.0
# Norway                      78             82.5                  77.0
# Poland                      55             78.0                  58.0
# Portugal                    56             81.2                  48.0
# Slovak Republic             60             77.3                  66.0
# Slovenia                    53             81.3                  64.0
# Spain                       70             83.4                  72.0
# Sweden                      86             82.4                  75.0
# Switzerland                 49             83.7                  78.0
# Turkey                      86             78.0                  69.0
# United Kingdom              69             81.2                  69.0
# United States               65             78.6                  88.0
# OECD - Total                68             80.2                  69.0
# Brazil                      79             74.8                   NaN
# Russia                      68             71.8                  43.0
# South Africa                73             57.5                   NaN
#
#                  Life satisfaction  Feeling safe walking alone at night  \
# Country
# Australia                      7.3                                 63.5
# Austria                        7.1                                 80.6
# Belgium                        6.9                                 70.1
# Canada                         7.4                                 82.2
# Chile                          6.5                                 47.9
# Colombia                       6.3                                 44.4
# Czech Republic                 6.7                                 72.3
# Denmark                        7.6                                 83.5
# Estonia                        5.7                                 69.0
# Finland                        7.6                                 85.1
# France                         6.5                                 70.5
# Germany                        7.0                                 72.5
# Greece                         5.4                                 60.0
# Hungary                        5.6                                 56.3
# Iceland                        7.5                                 86.0
# Ireland                        7.0                                 75.9
# Israel                         7.2                                 69.8
# Italy                          6.0                                 58.4
# Japan                          5.9                                 72.5
# Korea                          5.9                                 66.6
# Latvia                         5.9                                 62.4
# Lithuania                      5.9                                 55.9
# Luxembourg                     6.9                                 75.8
# Mexico                         6.5                                 41.8
# Netherlands                    7.4                                 82.0
# New Zealand                    7.3                                 65.7
# Norway                         7.6                                 90.1
# Poland                         6.1                                 67.3
# Portugal                       5.4                                 73.4
# Slovak Republic                6.2                                 63.5
# Slovenia                       5.9                                 86.1
# Spain                          6.3                                 82.1
# Sweden                         7.3                                 75.6
# Switzerland                    7.5                                 85.3
# Turkey                         5.5                                 59.8
# United Kingdom                 6.8                                 77.7
# United States                  6.9                                 73.9
# OECD - Total                   6.5                                 68.4
# Brazil                         6.4                                 35.6
# Russia                         5.8                                 52.8
# South Africa                   4.7                                 36.1
#
#                  Homicide rate  Employees working very long hours  \
# Country
# Australia                  1.1                              13.04
# Austria                    0.5                               6.66
# Belgium                    1.0                               4.75
# Canada                     1.3                               3.69
# Chile                      4.2                               9.72
# Colombia                  24.5                              26.56
# Czech Republic             0.5                               5.65
# Denmark                    0.6                               2.34
# Estonia                    3.1                               2.42
# Finland                    1.3                               3.81
# France                     0.5                               7.67
# Germany                    0.5                               4.26
# Greece                     0.8                               6.42
# Hungary                    1.0                               3.03
# Iceland                    0.5                              15.06
# Ireland                    0.7                               5.25
# Israel                     1.8                              15.45
# Italy                      0.6                               4.11
# Japan                      0.2                                NaN
# Korea                      1.0                                NaN
# Latvia                     4.8                               1.27
# Lithuania                  3.4                               0.54
# Luxembourg                 0.6                               3.82
# Mexico                    18.1                              28.70
# Netherlands                0.6                               0.42
# New Zealand                1.3                              15.11
# Norway                     0.4                               2.93
# Poland                     0.7                               5.95
# Portugal                   1.0                               8.27
# Slovak Republic            0.8                               4.14
# Slovenia                   0.6                               4.39
# Spain                      0.6                               4.01
# Sweden                     0.9                               1.07
# Switzerland                0.6                               0.37
# Turkey                     1.4                              32.64
# United Kingdom             0.2                              12.15
# United States              5.5                              11.09
# OECD - Total               3.7                              11.01
# Brazil                    26.7                               7.13
# Russia                     9.6                               0.14
# South Africa              13.7                              18.12
#
#                  Time devoted to leisure and personal care
# Country
# Australia                                            14.35
# Austria                                              14.55
# Belgium                                              15.70
# Canada                                               14.56
# Chile                                                  NaN
# Colombia                                               NaN
# Czech Republic                                         NaN
# Denmark                                              15.87
# Estonia                                              14.90
# Finland                                              15.17
# France                                               16.36
# Germany                                              15.62
# Greece                                                 NaN
# Hungary                                                NaN
# Iceland                                                NaN
# Ireland                                                NaN
# Israel                                                 NaN
# Italy                                                16.47
# Japan                                                  NaN
# Korea                                                14.70
# Latvia                                               13.83
# Lithuania                                              NaN
# Luxembourg                                             NaN
# Mexico                                                 NaN
# Netherlands                                            NaN
# New Zealand                                          14.87
# Norway                                               15.56
# Poland                                               14.42
# Portugal                                               NaN
# Slovak Republic                                        NaN
# Slovenia                                             14.75
# Spain                                                15.93
# Sweden                                               15.18
# Switzerland                                            NaN
# Turkey                                               14.79
# United Kingdom                                       14.92
# United States                                        14.44
# OECD - Total                                         14.98
# Brazil                                                 NaN
# Russia                                                 NaN
# South Africa                                         14.92

# %% [markdown]
# #### Head
#
# Trae los primeros n elementos

# %%
df.head(5)
# Out:
#            Dwellings without basic facilities  Housing expenditure  \
# Country
# Australia                                 NaN                 20.0
# Austria                                   0.9                 21.0
# Belgium                                   1.9                 21.0
# Canada                                    0.2                 22.0
# Chile                                     9.4                 18.0
#
#            Rooms per person  Household net adjusted disposable income  \
# Country
# Australia               NaN                                   32759.0
# Austria                 1.6                                   33541.0
# Belgium                 2.2                                   30364.0
# Canada                  2.6                                   30854.0
# Chile                   1.2                                       NaN
#
#            Household net wealth  Labour market insecurity  Employment rate  \
# Country
# Australia              427064.0                       5.4               73
# Austria                308325.0                       3.5               72
# Belgium                386006.0                       3.7               63
# Canada                 423849.0                       6.0               73
# Chile                  100967.0                       8.7               63
#
#            Long-term unemployment rate  Personal earnings  \
# Country
# Australia                         1.31            49126.0
# Austria                           1.84            50349.0
# Belgium                           3.54            49675.0
# Canada                            0.77            47622.0
# Chile                              NaN            25879.0
#
#            Quality of support network  Educational attainment  Student skills  \
# Country
# Australia                          95                    81.0           502.0
# Austria                            92                    85.0           492.0
# Belgium                            91                    77.0           503.0
# Canada                             93                    91.0           523.0
# Chile                              85                    65.0           443.0
#
#            Years in education  Air pollution  Water quality  \
# Country
# Australia                21.0              5             93
# Austria                  17.0             16             92
# Belgium                  19.3             15             84
# Canada                   17.3              7             91
# Chile                    17.5             16             71
#
#            Stakeholder engagement for developing regulations  Voter turnout  \
# Country
# Australia                                                2.7             91
# Austria                                                  1.3             80
# Belgium                                                  2.0             89
# Canada                                                   2.9             68
# Chile                                                    1.3             47
#
#            Life expectancy  Self-reported health  Life satisfaction  \
# Country
# Australia             82.5                  85.0                7.3
# Austria               81.7                  70.0                7.1
# Belgium               81.5                  74.0                6.9
# Canada                81.9                  88.0                7.4
# Chile                 79.9                  57.0                6.5
#
#            Feeling safe walking alone at night  Homicide rate  \
# Country
# Australia                                 63.5            1.1
# Austria                                   80.6            0.5
# Belgium                                   70.1            1.0
# Canada                                    82.2            1.3
# Chile                                     47.9            4.2
#
#            Employees working very long hours  \
# Country
# Australia                              13.04
# Austria                                 6.66
# Belgium                                 4.75
# Canada                                  3.69
# Chile                                   9.72
#
#            Time devoted to leisure and personal care
# Country
# Australia                                      14.35
# Austria                                        14.55
# Belgium                                        15.70
# Canada                                         14.56
# Chile                                            NaN

# %% [markdown]
# #### Tail
#
# Trae los últimos n elementos

# %%
df.tail(5)
# Out:
#                Dwellings without basic facilities  Housing expenditure  \
# Country
# United States                                 0.1                 19.0
# OECD - Total                                  4.4                 20.0
# Brazil                                        6.7                  NaN
# Russia                                       14.8                 18.0
# South Africa                                 37.0                 18.0
#
#                Rooms per person  Household net adjusted disposable income  \
# Country
# United States               2.4                                   45284.0
# OECD - Total                1.8                                   33604.0
# Brazil                      NaN                                       NaN
# Russia                      0.9                                       NaN
# South Africa                NaN                                       NaN
#
#                Household net wealth  Labour market insecurity  \
# Country
# United States              632100.0                       7.7
# OECD - Total               408376.0                       7.0
# Brazil                          NaN                       NaN
# Russia                          NaN                       NaN
# South Africa                    NaN                       NaN
#
#                Employment rate  Long-term unemployment rate  \
# Country
# United States               70                         0.66
# OECD - Total                68                         1.78
# Brazil                      61                          NaN
# Russia                      70                         1.59
# South Africa                43                        16.46
#
#                Personal earnings  Quality of support network  \
# Country
# United States            60558.0                          91
# OECD - Total             43241.0                          89
# Brazil                       NaN                          90
# Russia                       NaN                          89
# South Africa                 NaN                          88
#
#                Educational attainment  Student skills  Years in education  \
# Country
# United States                    91.0           488.0                17.2
# OECD - Total                     78.0           486.0                17.2
# Brazil                           49.0           395.0                16.2
# Russia                           94.0           492.0                16.2
# South Africa                     73.0             NaN                 NaN
#
#                Air pollution  Water quality  \
# Country
# United States             10             83
# OECD - Total              14             81
# Brazil                    10             73
# Russia                    15             55
# South Africa              22             67
#
#                Stakeholder engagement for developing regulations  \
# Country
# United States                                                3.1
# OECD - Total                                                 2.4
# Brazil                                                       2.2
# Russia                                                       NaN
# South Africa                                                 NaN
#
#                Voter turnout  Life expectancy  Self-reported health  \
# Country
# United States             65             78.6                  88.0
# OECD - Total              68             80.2                  69.0
# Brazil                    79             74.8                   NaN
# Russia                    68             71.8                  43.0
# South Africa              73             57.5                   NaN
#
#                Life satisfaction  Feeling safe walking alone at night  \
# Country
# United States                6.9                                 73.9
# OECD - Total                 6.5                                 68.4
# Brazil                       6.4                                 35.6
# Russia                       5.8                                 52.8
# South Africa                 4.7                                 36.1
#
#                Homicide rate  Employees working very long hours  \
# Country
# United States            5.5                              11.09
# OECD - Total             3.7                              11.01
# Brazil                  26.7                               7.13
# Russia                   9.6                               0.14
# South Africa            13.7                              18.12
#
#                Time devoted to leisure and personal care
# Country
# United States                                      14.44
# OECD - Total                                       14.98
# Brazil                                               NaN
# Russia                                               NaN
# South Africa                                       14.92

# %% [markdown]
# #### Sample
#
# Entrega n filas aleatorias

# %%
df.sample(5)
# Out:
#                  Dwellings without basic facilities  Housing expenditure  \
# Country
# Slovak Republic                                 1.2                 23.0
# France                                          0.5                 21.0
# Poland                                          3.0                 22.0
# Switzerland                                     0.1                 22.0
# Denmark                                         0.5                 23.0
#
#                  Rooms per person  Household net adjusted disposable income  \
# Country
# Slovak Republic               1.1                                   20474.0
# France                        1.8                                   31304.0
# Poland                        1.1                                   19814.0
# Switzerland                   1.9                                   37466.0
# Denmark                       1.9                                   29606.0
#
#                  Household net wealth  Labour market insecurity  \
# Country
# Slovak Republic              119696.0                       9.9
# France                       280653.0                       7.6
# Poland                       210991.0                       5.7
# Switzerland                       NaN                       NaN
# Denmark                      118637.0                       4.2
#
#                  Employment rate  Long-term unemployment rate  \
# Country
# Slovak Republic               66                         4.78
# France                        65                         4.00
# Poland                        66                         1.52
# Switzerland                   80                         1.82
# Denmark                       74                         1.31
#
#                  Personal earnings  Quality of support network  \
# Country
# Slovak Republic            24328.0                          91
# France                     43755.0                          90
# Poland                     27046.0                          86
# Switzerland                62283.0                          93
# Denmark                    51466.0                          95
#
#                  Educational attainment  Student skills  Years in education  \
# Country
# Slovak Republic                    91.0           463.0                15.8
# France                             78.0           496.0                16.5
# Poland                             92.0           504.0                17.6
# Switzerland                        88.0           506.0                17.5
# Denmark                            81.0           504.0                19.5
#
#                  Air pollution  Water quality  \
# Country
# Slovak Republic             21             85
# France                      13             81
# Poland                      22             82
# Switzerland                 15             95
# Denmark                      9             95
#
#                  Stakeholder engagement for developing regulations  \
# Country
# Slovak Republic                                                3.0
# France                                                         2.1
# Poland                                                         2.6
# Switzerland                                                    2.3
# Denmark                                                        2.0
#
#                  Voter turnout  Life expectancy  Self-reported health  \
# Country
# Slovak Republic             60             77.3                  66.0
# France                      75             82.4                  66.0
# Poland                      55             78.0                  58.0
# Switzerland                 49             83.7                  78.0
# Denmark                     86             80.9                  71.0
#
#                  Life satisfaction  Feeling safe walking alone at night  \
# Country
# Slovak Republic                6.2                                 63.5
# France                         6.5                                 70.5
# Poland                         6.1                                 67.3
# Switzerland                    7.5                                 85.3
# Denmark                        7.6                                 83.5
#
#                  Homicide rate  Employees working very long hours  \
# Country
# Slovak Republic            0.8                               4.14
# France                     0.5                               7.67
# Poland                     0.7                               5.95
# Switzerland                0.6                               0.37
# Denmark                    0.6                               2.34
#
#                  Time devoted to leisure and personal care
# Country
# Slovak Republic                                        NaN
# France                                               16.36
# Poland                                               14.42
# Switzerland                                            NaN
# Denmark                                              15.87

# %% [markdown]
# > **Pregunta ❓** Existe alguna forma de repetir el mismo muestreo aleatorio de datos?

# %%
df.sample(5, random_state=2)
# Out:
#            Dwellings without basic facilities  Housing expenditure  \
# Country
# Poland                                    3.0                 22.0
# Finland                                   0.5                 23.0
# Iceland                                   0.0                 24.0
# Australia                                 NaN                 20.0
# Belgium                                   1.9                 21.0
#
#            Rooms per person  Household net adjusted disposable income  \
# Country
# Poland                  1.1                                   19814.0
# Finland                 1.9                                   29943.0
# Iceland                 1.6                                       NaN
# Australia               NaN                                   32759.0
# Belgium                 2.2                                   30364.0
#
#            Household net wealth  Labour market insecurity  Employment rate  \
# Country
# Poland                 210991.0                       5.7               66
# Finland                200827.0                       3.9               70
# Iceland                     NaN                       0.7               86
# Australia              427064.0                       5.4               73
# Belgium                386006.0                       3.7               63
#
#            Long-term unemployment rate  Personal earnings  \
# Country
# Poland                            1.52            27046.0
# Finland                           2.13            42964.0
# Iceland                           0.26            61787.0
# Australia                         1.31            49126.0
# Belgium                           3.54            49675.0
#
#            Quality of support network  Educational attainment  Student skills  \
# Country
# Poland                             86                    92.0           504.0
# Finland                            95                    88.0           523.0
# Iceland                            98                    77.0           481.0
# Australia                          95                    81.0           502.0
# Belgium                            91                    77.0           503.0
#
#            Years in education  Air pollution  Water quality  \
# Country
# Poland                   17.6             22             82
# Finland                  19.8              6             95
# Iceland                  19.0              3             99
# Australia                21.0              5             93
# Belgium                  19.3             15             84
#
#            Stakeholder engagement for developing regulations  Voter turnout  \
# Country
# Poland                                                   2.6             55
# Finland                                                  2.2             67
# Iceland                                                  2.1             79
# Australia                                                2.7             91
# Belgium                                                  2.0             89
#
#            Life expectancy  Self-reported health  Life satisfaction  \
# Country
# Poland                78.0                  58.0                6.1
# Finland               81.5                  70.0                7.6
# Iceland               82.3                  76.0                7.5
# Australia             82.5                  85.0                7.3
# Belgium               81.5                  74.0                6.9
#
#            Feeling safe walking alone at night  Homicide rate  \
# Country
# Poland                                    67.3            0.7
# Finland                                   85.1            1.3
# Iceland                                   86.0            0.5
# Australia                                 63.5            1.1
# Belgium                                   70.1            1.0
#
#            Employees working very long hours  \
# Country
# Poland                                  5.95
# Finland                                 3.81
# Iceland                                15.06
# Australia                              13.04
# Belgium                                 4.75
#
#            Time devoted to leisure and personal care
# Country
# Poland                                         14.42
# Finland                                        15.17
# Iceland                                          NaN
# Australia                                      14.35
# Belgium                                        15.70

# %% [markdown]
# > **Pregunta ❓** ¿Cuál es la unidad más básica que los `DataFrames`?

# %%
df.values
# Out:
# array([[        nan, 2.00000e+01,         nan, 3.27590e+04, 4.27064e+05,
#         5.40000e+00, 7.30000e+01, 1.31000e+00, 4.91260e+04, 9.50000e+01,
#         8.10000e+01, 5.02000e+02, 2.10000e+01, 5.00000e+00, 9.30000e+01,
#         2.70000e+00, 9.10000e+01, 8.25000e+01, 8.50000e+01, 7.30000e+00,
#         6.35000e+01, 1.10000e+00, 1.30400e+01, 1.43500e+01],
#        [9.00000e-01, 2.10000e+01, 1.60000e+00, 3.35410e+04, 3.08325e+05,
#         3.50000e+00, 7.20000e+01, 1.84000e+00, 5.03490e+04, 9.20000e+01,
#         8.50000e+01, 4.92000e+02, 1.70000e+01, 1.60000e+01, 9.20000e+01,
#         1.30000e+00, 8.00000e+01, 8.17000e+01, 7.00000e+01, 7.10000e+00,
#         8.06000e+01, 5.00000e-01, 6.66000e+00, 1.45500e+01],
#         9.10000e+01, 4.88000e+02, 1.72000e+01, 1.00000e+01, 8.30000e+01,
#         3.10000e+00, 6.50000e+01, 7.86000e+01, 8.80000e+01, 6.90000e+00,
#         7.39000e+01, 5.50000e+00, 1.10900e+01, 1.44400e+01],
#        [4.40000e+00, 2.00000e+01, 1.80000e+00, 3.36040e+04, 4.08376e+05,
#         7.00000e+00, 6.80000e+01, 1.78000e+00, 4.32410e+04, 8.90000e+01,
#         7.80000e+01, 4.86000e+02, 1.72000e+01, 1.40000e+01, 8.10000e+01,
#         2.40000e+00, 6.80000e+01, 8.02000e+01, 6.90000e+01, 6.50000e+00,
#         6.84000e+01, 3.70000e+00, 1.10100e+01, 1.49800e+01],
#        [6.70000e+00,         nan,         nan,         nan,         nan,
#                 nan, 6.10000e+01,         nan,         nan, 9.00000e+01,
#         4.90000e+01, 3.95000e+02, 1.62000e+01, 1.00000e+01, 7.30000e+01,
#         2.20000e+00, 7.90000e+01, 7.48000e+01,         nan, 6.40000e+00,
#         3.56000e+01, 2.67000e+01, 7.13000e+00,         nan],
#        [1.48000e+01, 1.80000e+01, 9.00000e-01,         nan,         nan,
#                 nan, 7.00000e+01, 1.59000e+00,         nan, 8.90000e+01,
#         9.40000e+01, 4.92000e+02, 1.62000e+01, 1.50000e+01, 5.50000e+01,
#                 nan, 6.80000e+01, 7.18000e+01, 4.30000e+01, 5.80000e+00,
#         5.28000e+01, 9.60000e+00, 1.40000e-01,         nan],
#        [3.70000e+01, 1.80000e+01,         nan,         nan,         nan,
#                 nan, 4.30000e+01, 1.64600e+01,         nan, 8.80000e+01,
#         7.30000e+01,         nan,         nan, 2.20000e+01, 6.70000e+01,
#                 nan, 7.30000e+01, 5.75000e+01,         nan, 4.70000e+00,
#         3.61000e+01, 1.37000e+01, 1.81200e+01, 1.49200e+01]])

# %% [markdown]
# ---
#
# ## 3.- `Series`
#
# Los objetos tipo `pd.Series` son los objetos base de los DataFrames. Estos consisten en un arreglo unidimensional (que puede contener una sucesión de valores u objetos) asociados a un índice. Además, opcionalmente pueden llevar un nombre (que sería el equivalente al nombre de la columna de un DataFrame).

# %%
serie = pd.Series([1, 9, 7, -5, 3, 10], name="Mi serie")
serie
# Out:
# 0     1
# 1     9
# 2     7
# 3    -5
# 4     3
# 5    10
# Name: Mi serie, dtype: int64

# %% [markdown]
# ### Atributos básicos

# %%
serie.values
# Out:
# array([ 1,  9,  7, -5,  3, 10])

# %%
serie.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
serie.dtype
# Out:
# dtype('int64')

# %%
serie.name
# Out:
# 'Mi serie'

# %%
serie.shape
# Out:
# (6,)

# %% [markdown]
# ### Indexado de Series

# %% [markdown]
# Podemos acceder a cualquier elemento de una serie usando los mismos principios de indexado que en `numpy`:

# %%
serie
# Out:
# 0     1
# 1     9
# 2     7
# 3    -5
# 4     3
# 5    10
# Name: Mi serie, dtype: int64

# %%
serie[0]
# Out:
# 1

# %%
serie[0:2]
# Out:
# 0    1
# 1    9
# Name: Mi serie, dtype: int64

# %%
serie[0:4]
# Out:
# 0    1
# 1    9
# 2    7
# 3   -5
# Name: Mi serie, dtype: int64

# %% [markdown]
# ---
#
# ## 4.- Indexado de DataFrames
#
# En esta sección veremos como seleccionar filas y columnas a través de distintos tipos de indexados.
#
# <img src="./resources/subsets.png" alt="OECD Better life index"/>

# %%
df.head(5)
# Out:
#            Dwellings without basic facilities  Housing expenditure  \
# Country
# Australia                                 NaN                 20.0
# Austria                                   0.9                 21.0
# Belgium                                   1.9                 21.0
# Canada                                    0.2                 22.0
# Chile                                     9.4                 18.0
#
#            Rooms per person  Household net adjusted disposable income  \
# Country
# Australia               NaN                                   32759.0
# Austria                 1.6                                   33541.0
# Belgium                 2.2                                   30364.0
# Canada                  2.6                                   30854.0
# Chile                   1.2                                       NaN
#
#            Household net wealth  Labour market insecurity  Employment rate  \
# Country
# Australia              427064.0                       5.4               73
# Austria                308325.0                       3.5               72
# Belgium                386006.0                       3.7               63
# Canada                 423849.0                       6.0               73
# Chile                  100967.0                       8.7               63
#
#            Long-term unemployment rate  Personal earnings  \
# Country
# Australia                         1.31            49126.0
# Austria                           1.84            50349.0
# Belgium                           3.54            49675.0
# Canada                            0.77            47622.0
# Chile                              NaN            25879.0
#
#            Quality of support network  Educational attainment  Student skills  \
# Country
# Australia                          95                    81.0           502.0
# Austria                            92                    85.0           492.0
# Belgium                            91                    77.0           503.0
# Canada                             93                    91.0           523.0
# Chile                              85                    65.0           443.0
#
#            Years in education  Air pollution  Water quality  \
# Country
# Australia                21.0              5             93
# Austria                  17.0             16             92
# Belgium                  19.3             15             84
# Canada                   17.3              7             91
# Chile                    17.5             16             71
#
#            Stakeholder engagement for developing regulations  Voter turnout  \
# Country
# Australia                                                2.7             91
# Austria                                                  1.3             80
# Belgium                                                  2.0             89
# Canada                                                   2.9             68
# Chile                                                    1.3             47
#
#            Life expectancy  Self-reported health  Life satisfaction  \
# Country
# Australia             82.5                  85.0                7.3
# Austria               81.7                  70.0                7.1
# Belgium               81.5                  74.0                6.9
# Canada                81.9                  88.0                7.4
# Chile                 79.9                  57.0                6.5
#
#            Feeling safe walking alone at night  Homicide rate  \
# Country
# Australia                                 63.5            1.1
# Austria                                   80.6            0.5
# Belgium                                   70.1            1.0
# Canada                                    82.2            1.3
# Chile                                     47.9            4.2
#
#            Employees working very long hours  \
# Country
# Australia                              13.04
# Austria                                 6.66
# Belgium                                 4.75
# Canada                                  3.69
# Chile                                   9.72
#
#            Time devoted to leisure and personal care
# Country
# Australia                                      14.35
# Austria                                        14.55
# Belgium                                        15.70
# Canada                                         14.56
# Chile                                            NaN

# %% [markdown]
# ### Acceder a una serie en específico
#
#
#
# Volviendo a nuestro ejemplo, podemos acceder a las series de nuestro Dataset por medio de un indexador al cual se le provee el nombre de alguna columna.
#
# Por ejemplo:
#
# > **Water quality 💧**: Porcentaje de personas que informan estar satisfechas con la calidad del agua local

# %%
df['Water quality']
# Out:
# Country
# Australia          93
# Austria            92
# Belgium            84
# Canada             91
# Chile              71
# Colombia           75
# Czech Republic     87
# Denmark            95
# Estonia            84
# Finland            95
# France             81
# Germany            91
# Greece             69
# Hungary            77
# Iceland            99
# Ireland            85
# Israel             67
# Italy              71
# Japan              87
# Korea              76
# Latvia             79
# Lithuania          81
# Luxembourg         84
# Mexico             68
# Netherlands        93
# New Zealand        89
# Norway             98
# Poland             82
# Portugal           86
# Slovak Republic    85
# Slovenia           90
# Spain              72
# Sweden             96
# Switzerland        95
# Turkey             65
# United Kingdom     84
# United States      83
# OECD - Total       81
# Brazil             73
# Russia             55
# South Africa       67
# Name: Water quality, dtype: int64

# %% [markdown]
# ### Selector de Columnas

# %% [markdown]
# Veamos ahora cómo seleccionar un par de columnas en particular, como por ejemplo:
#
# > **Water quality 💧**: Porcentaje de personas que informan estar satisfechas con la calidad del agua local
#
# > **Air Pollution 🏙️**: Concentración promedio de partículas (PM2.5) en ciudades con poblaciones mayores de 100,000 personas

# %%
df[['Water quality', 'Air pollution']]
# Out:
#                  Water quality  Air pollution
# Country
# Australia                   93              5
# Austria                     92             16
# Belgium                     84             15
# Canada                      91              7
# Chile                       71             16
# Colombia                    75             10
# Czech Republic              87             20
# Denmark                     95              9
# Estonia                     84              8
# Finland                     95              6
# France                      81             13
# Germany                     91             14
# Greece                      69             18
# Hungary                     77             19
# Iceland                     99              3
# Ireland                     85              7
# Israel                      67             21
# Italy                       71             18
# Japan                       87             14
# Korea                       76             28
# Latvia                      79             11
# Lithuania                   81             14
# Luxembourg                  84             12
# Mexico                      68             16
# Netherlands                 93             14
# New Zealand                 89              5
# Norway                      98              5
# Poland                      82             22
# Portugal                    86             10
# Slovak Republic             85             21
# Slovenia                    90             16
# Spain                       72             11
# Sweden                      96              6
# Switzerland                 95             15
# Turkey                      65             20
# United Kingdom              84             11
# United States               83             10
# OECD - Total                81             14
# Brazil                      73             10
# Russia                      55             15
# South Africa                67             22

# %% [markdown]
# ### Selector de filas
#
# Para seleccionar filas, podemos entregar un indexador de filas al estilo `numpy`:

# %%
df[0:10]
# Out:
#                 Dwellings without basic facilities  Housing expenditure  \
# Country
# Australia                                      NaN                 20.0
# Austria                                        0.9                 21.0
# Belgium                                        1.9                 21.0
# Canada                                         0.2                 22.0
# Chile                                          9.4                 18.0
# Colombia                                      23.9                 17.0
# Czech Republic                                 0.7                 24.0
# Denmark                                        0.5                 23.0
# Estonia                                        7.0                 17.0
# Finland                                        0.5                 23.0
#
#                 Rooms per person  Household net adjusted disposable income  \
# Country
# Australia                    NaN                                   32759.0
# Austria                      1.6                                   33541.0
# Belgium                      2.2                                   30364.0
# Canada                       2.6                                   30854.0
# Chile                        1.2                                       NaN
# Colombia                     1.2                                       NaN
# Czech Republic               1.4                                   21453.0
# Denmark                      1.9                                   29606.0
# Estonia                      1.6                                   19697.0
# Finland                      1.9                                   29943.0
#
#                 Household net wealth  Labour market insecurity  \
# Country
# Australia                   427064.0                       5.4
# Austria                     308325.0                       3.5
# Belgium                     386006.0                       3.7
# Canada                      423849.0                       6.0
# Chile                       100967.0                       8.7
# Colombia                         NaN                       NaN
# Czech Republic                   NaN                       3.1
# Denmark                     118637.0                       4.2
# Estonia                     159373.0                       3.8
# Finland                     200827.0                       3.9
#
#                 Employment rate  Long-term unemployment rate  \
# Country
# Australia                    73                         1.31
# Austria                      72                         1.84
# Belgium                      63                         3.54
# Canada                       73                         0.77
# Chile                        63                          NaN
# Colombia                     67                         0.79
# Czech Republic               74                         1.04
# Denmark                      74                         1.31
# Estonia                      74                         1.92
# Finland                      70                         2.13
#
#                 Personal earnings  Quality of support network  \
# Country
# Australia                 49126.0                          95
# Austria                   50349.0                          92
# Belgium                   49675.0                          91
# Canada                    47622.0                          93
# Chile                     25879.0                          85
# Colombia                      NaN                          89
# Czech Republic            25372.0                          91
# Denmark                   51466.0                          95
# Estonia                   24336.0                          92
# Finland                   42964.0                          95
#
#                 Educational attainment  Student skills  Years in education  \
# Country
# Australia                         81.0           502.0                21.0
# Austria                           85.0           492.0                17.0
# Belgium                           77.0           503.0                19.3
# Canada                            91.0           523.0                17.3
# Chile                             65.0           443.0                17.5
# Colombia                          54.0           410.0                14.1
# Czech Republic                    94.0           491.0                17.9
# Denmark                           81.0           504.0                19.5
# Estonia                           89.0           524.0                17.7
# Finland                           88.0           523.0                19.8
#
#                 Air pollution  Water quality  \
# Country
# Australia                   5             93
# Austria                    16             92
# Belgium                    15             84
# Canada                      7             91
# Chile                      16             71
# Colombia                   10             75
# Czech Republic             20             87
# Denmark                     9             95
# Estonia                     8             84
# Finland                     6             95
#
#                 Stakeholder engagement for developing regulations  \
# Country
# Australia                                                     2.7
# Austria                                                       1.3
# Belgium                                                       2.0
# Canada                                                        2.9
# Chile                                                         1.3
# Colombia                                                      1.4
# Czech Republic                                                1.6
# Denmark                                                       2.0
# Estonia                                                       2.7
# Finland                                                       2.2
#
#                 Voter turnout  Life expectancy  Self-reported health  \
# Country
# Australia                  91             82.5                  85.0
# Austria                    80             81.7                  70.0
# Belgium                    89             81.5                  74.0
# Canada                     68             81.9                  88.0
# Chile                      47             79.9                  57.0
# Colombia                   53             76.2                   NaN
# Czech Republic             61             79.1                  60.0
# Denmark                    86             80.9                  71.0
# Estonia                    64             77.8                  53.0
# Finland                    67             81.5                  70.0
#
#                 Life satisfaction  Feeling safe walking alone at night  \
# Country
# Australia                     7.3                                 63.5
# Austria                       7.1                                 80.6
# Belgium                       6.9                                 70.1
# Canada                        7.4                                 82.2
# Chile                         6.5                                 47.9
# Colombia                      6.3                                 44.4
# Czech Republic                6.7                                 72.3
# Denmark                       7.6                                 83.5
# Estonia                       5.7                                 69.0
# Finland                       7.6                                 85.1
#
#                 Homicide rate  Employees working very long hours  \
# Country
# Australia                 1.1                              13.04
# Austria                   0.5                               6.66
# Belgium                   1.0                               4.75
# Canada                    1.3                               3.69
# Chile                     4.2                               9.72
# Colombia                 24.5                              26.56
# Czech Republic            0.5                               5.65
# Denmark                   0.6                               2.34
# Estonia                   3.1                               2.42
# Finland                   1.3                               3.81
#
#                 Time devoted to leisure and personal care
# Country
# Australia                                           14.35
# Austria                                             14.55
# Belgium                                             15.70
# Canada                                              14.56
# Chile                                                 NaN
# Colombia                                              NaN
# Czech Republic                                        NaN
# Denmark                                             15.87
# Estonia                                             14.90
# Finland                                             15.17

# %% [markdown]
# > **Pregunta ❓**: ¿Cómo seleccionamos al mismo tiempo filas y columnas?

# %%
df[['Water quality']][9: 10]
# Out:
#          Water quality
# Country
# Finland             95

# %%
df[[filas], [columnas]]

# %%
df.loc[0: 3, [2, 4]]

# %% [markdown]
# ### Loc: Indexador por etiquetas
#
# Permite acceder ciertos elementos por nombre de columnas y nombre de índices

# %%
df.loc[
    ["Chile", "Mexico", "Brazil", "Colombia"], # <- filas
    ["Water quality", "Air pollution"]         # <- columnas
]
# Out:
#           Water quality  Air pollution
# Country
# Chile                71             16
# Mexico               68             16
# Brazil               73             10
# Colombia             75             10

# %%
df.loc[
    ["Chile", "Mexico", "Brazil", "Colombia"], # <- filas
    :                                          # <- columnas
]
# Out:
#           Dwellings without basic facilities  Housing expenditure  \
# Country
# Chile                                    9.4                 18.0
# Mexico                                  25.5                 20.0
# Brazil                                   6.7                  NaN
# Colombia                                23.9                 17.0
#
#           Rooms per person  Household net adjusted disposable income  \
# Country
# Chile                  1.2                                       NaN
# Mexico                 1.0                                       NaN
# Brazil                 NaN                                       NaN
# Colombia               1.2                                       NaN
#
#           Household net wealth  Labour market insecurity  Employment rate  \
# Country
# Chile                 100967.0                       8.7               63
# Mexico                     NaN                       5.5               61
# Brazil                     NaN                       NaN               61
# Colombia                   NaN                       NaN               67
#
#           Long-term unemployment rate  Personal earnings  \
# Country
# Chile                             NaN            25879.0
# Mexico                           0.07            15314.0
# Brazil                            NaN                NaN
# Colombia                         0.79                NaN
#
#           Quality of support network  Educational attainment  Student skills  \
# Country
# Chile                             85                    65.0           443.0
# Mexico                            81                    38.0           416.0
# Brazil                            90                    49.0           395.0
# Colombia                          89                    54.0           410.0
#
#           Years in education  Air pollution  Water quality  \
# Country
# Chile                   17.5             16             71
# Mexico                  15.2             16             68
# Brazil                  16.2             10             73
# Colombia                14.1             10             75
#
#           Stakeholder engagement for developing regulations  Voter turnout  \
# Country
# Chile                                                   1.3             47
# Mexico                                                  3.2             63
# Brazil                                                  2.2             79
# Colombia                                                1.4             53
#
#           Life expectancy  Self-reported health  Life satisfaction  \
# Country
# Chile                79.9                  57.0                6.5
# Mexico               75.4                  66.0                6.5
# Brazil               74.8                   NaN                6.4
# Colombia             76.2                   NaN                6.3
#
#           Feeling safe walking alone at night  Homicide rate  \
# Country
# Chile                                    47.9            4.2
# Mexico                                   41.8           18.1
# Brazil                                   35.6           26.7
# Colombia                                 44.4           24.5
#
#           Employees working very long hours  \
# Country
# Chile                                  9.72
# Mexico                                28.70
# Brazil                                 7.13
# Colombia                              26.56
#
#           Time devoted to leisure and personal care
# Country
# Chile                                           NaN
# Mexico                                          NaN
# Brazil                                          NaN
# Colombia                                        NaN

# %%
df.loc[
    :                                        , # <- filas
    ["Water quality", "Air pollution"]         # <- columnas
]
# Out:
#                  Water quality  Air pollution
# Country
# Australia                   93              5
# Austria                     92             16
# Belgium                     84             15
# Canada                      91              7
# Chile                       71             16
# Colombia                    75             10
# Czech Republic              87             20
# Denmark                     95              9
# Estonia                     84              8
# Finland                     95              6
# France                      81             13
# Germany                     91             14
# Greece                      69             18
# Hungary                     77             19
# Iceland                     99              3
# Ireland                     85              7
# Israel                      67             21
# Italy                       71             18
# Japan                       87             14
# Korea                       76             28
# Latvia                      79             11
# Lithuania                   81             14
# Luxembourg                  84             12
# Mexico                      68             16
# Netherlands                 93             14
# New Zealand                 89              5
# Norway                      98              5
# Poland                      82             22
# Portugal                    86             10
# Slovak Republic             85             21
# Slovenia                    90             16
# Spain                       72             11
# Sweden                      96              6
# Switzerland                 95             15
# Turkey                      65             20
# United Kingdom              84             11
# United States               83             10
# OECD - Total                81             14
# Brazil                      73             10
# Russia                      55             15
# South Africa                67             22

# %% [markdown]
# > **Pregunta ❓**: Y si queremos usar filas con indexadores numéricos?

# %%
# no funcionaba porque nuestros índices son los países, no números.
df.loc[[5, 7, 12], :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 df.loc[[5, 7, 12], :]
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:889, in _LocationIndexer.__getitem__(self, key)
#     886         with suppress(KeyError, IndexError, AttributeError):
#     887             # AttributeError for IntervalTree get_value
#     888             return self.obj._get_value(*key, takeable=self._takeable)
# --> 889     return self._getitem_tuple(key)
#     890 else:
#     891     # we by definition only have the 0th axis
#     892     axis = self.axis or 0
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1069, in _LocIndexer._getitem_tuple(self, tup)
#    1066 if self._multi_take_opportunity(tup):
#    1067     return self._multi_take(tup)
# -> 1069 return self._getitem_tuple_same_dim(tup)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:775, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     772 if com.is_null_slice(key):
#     773     continue
# --> 775 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776 # We should never have retval.ndim < self.ndim, as that should
#     777 #  be handled by the _getitem_lowerdim call above.
#     778 assert retval.ndim == self.ndim
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1113, in _LocIndexer._getitem_axis(self, key, axis)
#    1110     if hasattr(key, "ndim") and key.ndim > 1:
#    1111         raise ValueError("Cannot index with multidimensional key")
# -> 1113     return self._getitem_iterable(key, axis=axis)
#    1115 # nested tuple slicing
#    1116 if is_nested_tuple(key, labels):
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1053, in _LocIndexer._getitem_iterable(self, key, axis)
#    1050 self._validate_key(key, axis)
#    1052 # A collection of keys
# -> 1053 keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054 return self.obj._reindex_with_indexers(
#    1055     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1056 )
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1266, in _LocIndexer._get_listlike_indexer(self, key, axis, raise_missing)
#    1263 else:
#    1264     keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
# -> 1266 self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267 return keyarr, indexer
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1308, in _LocIndexer._validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306 if missing == len(indexer):
#    1307     axis_name = self.obj._get_axis_name(axis)
# -> 1308     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1310 ax = self.obj._get_axis(axis)
#    1312 # We (temporarily) allow for some missing keys with .loc, except in
#    1313 # some cases (e.g. setting) in which "raise_missing" will be False
#
# KeyError: "None of [Int64Index([5, 7, 12], dtype='int64', name='Country')] are in the [index]"

# %%
df.loc[0:5, ["Water quality", "Air pollution"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 df.loc[0:5, ["Water quality", "Air pollution"]]
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:889, in _LocationIndexer.__getitem__(self, key)
#     886         with suppress(KeyError, IndexError, AttributeError):
#     887             # AttributeError for IntervalTree get_value
#     888             return self.obj._get_value(*key, takeable=self._takeable)
# --> 889     return self._getitem_tuple(key)
#     890 else:
#     891     # we by definition only have the 0th axis
#     892     axis = self.axis or 0
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1069, in _LocIndexer._getitem_tuple(self, tup)
#    1066 if self._multi_take_opportunity(tup):
#    1067     return self._multi_take(tup)
# -> 1069 return self._getitem_tuple_same_dim(tup)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:775, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     772 if com.is_null_slice(key):
#     773     continue
# --> 775 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776 # We should never have retval.ndim < self.ndim, as that should
#     777 #  be handled by the _getitem_lowerdim call above.
#     778 assert retval.ndim == self.ndim
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1102, in _LocIndexer._getitem_axis(self, key, axis)
#    1100 if isinstance(key, slice):
#    1101     self._validate_key(key, axis)
# -> 1102     return self._get_slice_axis(key, axis=axis)
#    1103 elif com.is_bool_indexer(key):
#    1104     return self._getbool_axis(key, axis=axis)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1136, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1133     return obj.copy(deep=False)
#    1135 labels = obj._get_axis(axis)
# -> 1136 indexer = labels.slice_indexer(
#    1137     slice_obj.start, slice_obj.stop, slice_obj.step, kind="loc"
#    1138 )
#    1140 if isinstance(indexer, slice):
#    1141     return self.obj._slice(indexer, axis=axis)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5278, in Index.slice_indexer(self, start, end, step, kind)
#    5232 def slice_indexer(
#    5233     self,
#    5234     start: Optional[Label] = None,
#    (...)
#    5237     kind: Optional[str_t] = None,
#    5238 ) -> slice:
#    5239     """
#    5240     Compute the slice indexer for input labels and step.
#    5241
#    (...)
#    5276     slice(1, 3, None)
#    5277     """
# -> 5278     start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5280     # return a slice
#    5281     if not is_scalar(start_slice):
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5477, in Index.slice_locs(self, start, end, step, kind)
#    5475 start_slice = None
#    5476 if start is not None:
# -> 5477     start_slice = self.get_slice_bound(start, "left", kind)
#    5478 if start_slice is None:
#    5479     start_slice = 0
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5387, in Index.get_slice_bound(self, label, side, kind)
#    5383 original_label = label
#    5385 # For datetime indices label may be a string that has to be converted
#    5386 # to datetime boundary according to its resolution.
# -> 5387 label = self._maybe_cast_slice_bound(label, side, kind)
#    5389 # we need to look up the label
#    5390 try:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5339, in Index._maybe_cast_slice_bound(self, label, side, kind)
#    5334 # We are a plain index here (sub-class override this method if they
#    5335 # wish to have special treatment for floats/ints, e.g. Float64Index and
#    5336 # datetimelike Indexes
#    5337 # reject them, if index does not contain label
#    5338 if (is_float(label) or is_integer(label)) and label not in self.values:
# -> 5339     raise self._invalid_indexer("slice", label)
#    5341 return label
#
# TypeError: cannot do slice indexing on Index with these indexers [0] of type int

# %% [markdown]
# ### Iloc: Indexador por Índices
#
# Para seleccionar por índices debemos utilizar otro tipo de indexador: `iloc`

# %%
df.iloc[8:12, :]
# Out:
#          Dwellings without basic facilities  Housing expenditure  \
# Country
# Estonia                                 7.0                 17.0
# Finland                                 0.5                 23.0
# France                                  0.5                 21.0
# Germany                                 0.2                 20.0
#
#          Rooms per person  Household net adjusted disposable income  \
# Country
# Estonia               1.6                                   19697.0
# Finland               1.9                                   29943.0
# France                1.8                                   31304.0
# Germany               1.8                                   34294.0
#
#          Household net wealth  Labour market insecurity  Employment rate  \
# Country
# Estonia              159373.0                       3.8               74
# Finland              200827.0                       3.9               70
# France               280653.0                       7.6               65
# Germany              259667.0                       2.7               75
#
#          Long-term unemployment rate  Personal earnings  \
# Country
# Estonia                         1.92            24336.0
# Finland                         2.13            42964.0
# France                          4.00            43755.0
# Germany                         1.57            47585.0
#
#          Quality of support network  Educational attainment  Student skills  \
# Country
# Estonia                          92                    89.0           524.0
# Finland                          95                    88.0           523.0
# France                           90                    78.0           496.0
# Germany                          90                    87.0           508.0
#
#          Years in education  Air pollution  Water quality  \
# Country
# Estonia                17.7              8             84
# Finland                19.8              6             95
# France                 16.5             13             81
# Germany                18.1             14             91
#
#          Stakeholder engagement for developing regulations  Voter turnout  \
# Country
# Estonia                                                2.7             64
# Finland                                                2.2             67
# France                                                 2.1             75
# Germany                                                1.8             76
#
#          Life expectancy  Self-reported health  Life satisfaction  \
# Country
# Estonia             77.8                  53.0                5.7
# Finland             81.5                  70.0                7.6
# France              82.4                  66.0                6.5
# Germany             81.1                  65.0                7.0
#
#          Feeling safe walking alone at night  Homicide rate  \
# Country
# Estonia                                 69.0            3.1
# Finland                                 85.1            1.3
# France                                  70.5            0.5
# Germany                                 72.5            0.5
#
#          Employees working very long hours  \
# Country
# Estonia                               2.42
# Finland                               3.81
# France                                7.67
# Germany                               4.26
#
#          Time devoted to leisure and personal care
# Country
# Estonia                                      14.90
# Finland                                      15.17
# France                                       16.36
# Germany                                      15.62

# %%
df.iloc[:, 0:3]
# Out:
#                  Dwellings without basic facilities  Housing expenditure  \
# Country
# Australia                                       NaN                 20.0
# Austria                                         0.9                 21.0
# Belgium                                         1.9                 21.0
# Canada                                          0.2                 22.0
# Chile                                           9.4                 18.0
# Colombia                                       23.9                 17.0
# Czech Republic                                  0.7                 24.0
# Denmark                                         0.5                 23.0
# Estonia                                         7.0                 17.0
# Finland                                         0.5                 23.0
# France                                          0.5                 21.0
# Germany                                         0.2                 20.0
# Greece                                          0.5                 23.0
# Hungary                                         4.7                 19.0
# Iceland                                         0.0                 24.0
# Ireland                                         1.0                 20.0
# Israel                                          NaN                  NaN
# Italy                                           0.7                 23.0
# Japan                                           6.4                 22.0
# Korea                                           2.5                 15.0
# Latvia                                         13.9                 23.0
# Lithuania                                      13.6                 19.0
# Luxembourg                                      0.5                 21.0
# Mexico                                         25.5                 20.0
# Netherlands                                     0.1                 19.0
# New Zealand                                     NaN                 26.0
# Norway                                          0.0                 17.0
# Poland                                          3.0                 22.0
# Portugal                                        1.0                 21.0
# Slovak Republic                                 1.2                 23.0
# Slovenia                                        0.4                 18.0
# Spain                                           0.1                 21.0
# Sweden                                          0.0                 19.0
# Switzerland                                     0.1                 22.0
# Turkey                                          8.0                 20.0
# United Kingdom                                  0.3                 26.0
# United States                                   0.1                 19.0
# OECD - Total                                    4.4                 20.0
# Brazil                                          6.7                  NaN
# Russia                                         14.8                 18.0
# South Africa                                   37.0                 18.0
#
#                  Rooms per person
# Country
# Australia                     NaN
# Austria                       1.6
# Belgium                       2.2
# Canada                        2.6
# Chile                         1.2
# Colombia                      1.2
# Czech Republic                1.4
# Denmark                       1.9
# Estonia                       1.6
# Finland                       1.9
# France                        1.8
# Germany                       1.8
# Greece                        1.2
# Hungary                       1.2
# Iceland                       1.6
# Ireland                       2.1
# Israel                        1.2
# Italy                         1.4
# Japan                         1.9
# Korea                         1.5
# Latvia                        1.2
# Lithuania                     1.5
# Luxembourg                    1.9
# Mexico                        1.0
# Netherlands                   1.9
# New Zealand                   2.4
# Norway                        2.1
# Poland                        1.1
# Portugal                      1.7
# Slovak Republic               1.1
# Slovenia                      1.5
# Spain                         1.9
# Sweden                        1.7
# Switzerland                   1.9
# Turkey                        1.0
# United Kingdom                1.9
# United States                 2.4
# OECD - Total                  1.8
# Brazil                        NaN
# Russia                        0.9
# South Africa                  NaN

# %%
df.iloc[:, [14]]
# Out:
#                  Water quality
# Country
# Australia                   93
# Austria                     92
# Belgium                     84
# Canada                      91
# Chile                       71
# Colombia                    75
# Czech Republic              87
# Denmark                     95
# Estonia                     84
# Finland                     95
# France                      81
# Germany                     91
# Greece                      69
# Hungary                     77
# Iceland                     99
# Ireland                     85
# Israel                      67
# Italy                       71
# Japan                       87
# Korea                       76
# Latvia                      79
# Lithuania                   81
# Luxembourg                  84
# Mexico                      68
# Netherlands                 93
# New Zealand                 89
# Norway                      98
# Poland                      82
# Portugal                    86
# Slovak Republic             85
# Slovenia                    90
# Spain                       72
# Sweden                      96
# Switzerland                 95
# Turkey                      65
# United Kingdom              84
# United States               83
# OECD - Total                81
# Brazil                      73
# Russia                      55
# South Africa                67

# %% [markdown]
# ### Mascaras 🎭: Selección por Booleanos
#
#
# Una operación interesante de selcción es usar un arreglo de booleanos para seleccionar datos.

# %%
len(df)

# %% [markdown]
# > **Pregunta ❓**: ¿Cómo podríamos obtener aquellos países cuya 80% o más de su población estén conformes con la calidad del agua?

# %%
mascara = df["Water quality"] >= 101
mascara
# Out:
# Country
# Australia          False
# Austria            False
# Belgium            False
# Canada             False
# Chile              False
# Colombia           False
# Czech Republic     False
# Denmark            False
# Estonia            False
# Finland            False
# France             False
# Germany            False
# Greece             False
# Hungary            False
# Iceland            False
# Ireland            False
# Israel             False
# Italy              False
# Japan              False
# Korea              False
# Latvia             False
# Lithuania          False
# Luxembourg         False
# Mexico             False
# Netherlands        False
# New Zealand        False
# Norway             False
# Poland             False
# Portugal           False
# Slovak Republic    False
# Slovenia           False
# Spain              False
# Sweden             False
# Switzerland        False
# Turkey             False
# United Kingdom     False
# United States      False
# OECD - Total       False
# Brazil             False
# Russia             False
# South Africa       False
# Name: Water quality, dtype: bool

# %%
df.loc[mascara, ['Water quality']]
# Out:
# Empty DataFrame
# Columns: [Water quality]
# Index: []
