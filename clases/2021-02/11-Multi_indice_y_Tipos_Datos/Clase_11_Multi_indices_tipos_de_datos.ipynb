# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Objetivos-de-la-Clase" data-toc-modified-id="Objetivos-de-la-Clase-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Objetivos de la Clase</a></span><ul class="toc-item"><li><span><a href="#Roadmap" data-toc-modified-id="Roadmap-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Roadmap</a></span></li></ul></li><li><span><a href="#Datasets-de-Hoy" data-toc-modified-id="Datasets-de-Hoy-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Datasets de Hoy</a></span><ul class="toc-item"><li><span><a href="#Índices-para-una-Vida-Mejor" data-toc-modified-id="Índices-para-una-Vida-Mejor-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Índices para una Vida Mejor</a></span></li><li><span><a href="#Dataset-de-Temperaturas-Globales" data-toc-modified-id="Dataset-de-Temperaturas-Globales-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Dataset de Temperaturas Globales</a></span></li></ul></li><li><span><a href="#Multi-Índice" data-toc-modified-id="Multi-Índice-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Multi-Índice</a></span><ul class="toc-item"><li><span><a href="#IndexSlice" data-toc-modified-id="IndexSlice-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>IndexSlice</a></span></li><li><span><a href="#Descartar-Índices" data-toc-modified-id="Descartar-Índices-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Descartar Índices</a></span></li></ul></li><li><span><a href="#Strings" data-toc-modified-id="Strings-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Strings</a></span><ul class="toc-item"><li><span><a href="#Métodos-de-la-Clase-String" data-toc-modified-id="Métodos-de-la-Clase-String-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Métodos de la Clase String</a></span></li><li><span><a href="#Strings-En-Las-Series" data-toc-modified-id="Strings-En-Las-Series-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Strings En Las Series</a></span><ul class="toc-item"><li><span><a href="#Len,-Lower,-Upper,-Title-y-Capitalize" data-toc-modified-id="Len,-Lower,-Upper,-Title-y-Capitalize-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Len, Lower, Upper, Title y Capitalize</a></span></li><li><span><a href="#Contains,-Split-y-Join" data-toc-modified-id="Contains,-Split-y-Join-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Contains, Split y Join</a></span></li><li><span><a href="#Replace" data-toc-modified-id="Replace-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Replace</a></span><ul class="toc-item"><li><span><a href="#Expresiones-Regulares" data-toc-modified-id="Expresiones-Regulares-4.2.3.1"><span class="toc-item-num">4.2.3.1&nbsp;&nbsp;</span>Expresiones Regulares</a></span></li></ul></li></ul></li><li><span><a href="#Apply" data-toc-modified-id="Apply-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Apply</a></span><ul class="toc-item"><li><span><a href="#Preprocesamiento-Completo" data-toc-modified-id="Preprocesamiento-Completo-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Preprocesamiento Completo</a></span></li><li><span><a href="#Concatenación" data-toc-modified-id="Concatenación-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Concatenación</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Clase 11: Multi-Indices y Tipos de Datos
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# **Profesor: Pablo Badilla**
#
# ## Objetivos de la Clase
#
# - Comprender como unir distintas fuentes de datos a partir de `concatenaciones` y `merge`.
#
# ### Roadmap
#
#
# **Unidad 2: Manejo de Datos con Pandas y AED**
#
# - [X] Introducción a pandas: DataFrames, Series, Operaciones básicas y Filtrado.
# - [X] Agregaciones.
# - [X] Visualizaciones interactivas usando Plotly.
# - [X] Concatenaciones y Merge de Dataframes.
# - [ ] Multi-índices y Trabajo con strings y datos temporales, categóricos y ordinales en Pandas.
# - [ ] Análisis exploratorio de Datos (AED).

# %%
import pandas as pd

# %% [markdown]
# ## Datasets de Hoy
#
# ### Índices para una Vida Mejor
#
# Nuevamente, seguiremos usando los datos de índices para una Vida Mejor de la OECD:
#
#
# <img src="./resources/oecd.png" alt="OECD Better life index"/>
#
#
# http://www.oecdbetterlifeindex.org/
#
# https://stats.oecd.org/index.aspx?DataSetCode=BLI
#
# Son 11 temas considerados como esenciales para el bienestar de la población. Cada crierio contiene uno o mas indicadores
#
# | Tema | Indicador (Inglés) | Indicador (Español) | Unidad | Descripción |
# |---|---|---|---|---|
# | Vivienda 🏠 | Dwellings without basic facilities | Vivienda con Instalaciones Básicas | Porcentaje | Porcentaje de personas con inodoros de agua corriente dentro del hogar, año disponible más reciente |
# |  | Housing expenditure | Gastos en Vivienda | Porcentaje | Proporción de costos de vivienda en el ingreso neto ajustado de las familias, año disponible más reciente |
# |  | Rooms per person | Habitaciones por Persona | Ratio | Número promedio de habitaciones compartidas por persona en una vivienda, año disponible más reciente |
# | Ingresos 💰 | Household net adjusted disposable income | Ingreso Familiar Disponible | US Dollar | Cantidad promedio de dinero que una familia gana al año, después de impuestos, año disponible más reciente |
# |  | Household net wealth | Patrimonio Neto Familiar | US Dollar | Valor total promedio de los activos financieros de una familia (ahorros, acciones) menos sus pasivos (créditos), año disponible más reciente |
# | Empleo ⚙️ | Labour market insecurity | Seguridad en el Empleo | Porcentaje | Pérdida esperada de ingresos cuando alguien queda desempleado, año disponible más reciente |
# |  | Employment rate | Tasa de Empleo | Porcentaje | Porcentaje de personas, de 15 a 64 años de edad, actualmente con empleo remunerado, año disponible más reciente |
# |  | Long-term unemployment rate | Tasa de Empleo a Largo Plazo | Porcentaje | Porcentaje de personas, de 15 a 64 años de edad, que no trabajan pero que han buscado empleo activamente durante más de un año, año disponible más reciente |
# |  | Personal earnings | Ingresos Personales | US Dollar | Ingresos anuales promedio por empleado de tiempo completo, año disponible más reciente |
# | Comunidad 🧑‍🤝‍🧑   | Quality of support network  | Calidad del Apoyo Social | Porcentaje | Porcentaje de personas con amigos o parientes en quienes confiar en caso de necesidad |
# | Educación 📚 | Educational attainment | Nivel de Educación | Porcentaje | Porcentaje de personas, de 25 a 64 años de edad, graduadas por lo menos de educación media superior, año disponible más reciente |
# |  | Student skills | Competencias de estudiantes en matemáticas, lectura y ciencias | Puntaje promedio | Desempeño promedio de estudiantes de 15 años de edad, según PISA (Programa para la Evaluación Internacional de Estudiantes) |
# |  | Years in education  | Nivel de educación | Años | Duración promedio de la educación formal en la que un niño de cinco años de edad puede esperar matricularse durante su vida |
# | Medio Ambiente 🌳 | Air pollution | Contaminación del Aire | Microgramos por metro cúbico | Concentración promedio de partículas (PM2.5) en ciudades con poblaciones mayores de 100,000 personas, medida en microgramos por metro cúbico, año disponible más reciente |
# |  | Water quality | Calidad del Agua | Porcentaje | Porcentaje de personas que informan estar satisfechas con la calidad del agua local |
# | Compromiso Cívico 🗳️  | Stakeholder engagement for developing regulations | Participación de los interesados en la elaboración de regulaciones | Puntaje promedio | Nivel de transparencia gubernamental al preparar las regulaciones, año disponible más reciente |
# |  | Voter turnout | Participación electoral | Porcentaje | Porcentaje de votantes registrados que votaron durante las elecciones recientes, año disponible más reciente |
# | Salud ⚕️ | Life expectancy | Esperanza de vida | Años | Número promedio de años que una persona puede esperar vivir, año disponible más reciente |
# |  | Self-reported health | Salud según informan las personas | Porcentaje | Porcentaje de personas que informan que su salud es «buena o muy buena», año disponible más reciente |
# | Satisfacción ✨ | Life satisfaction | Satisfacción ante la vida | Puntaje promedio | Autoevaluación promedio de satisfacción ante la vida, en una escala de 0 a 10 |
# | Seguridad 🌃 | Feeling safe walking alone at night | Sentimiento de seguridad al caminar solos por la noche | Porcentaje | Porcentaje de personas que reportan sentirse seguras al caminar solas por la noche  |
# |  | Homicide rate | Tasa de homicidios | Ratio | Número promedio de homicidios reportados por 100,000 personas, año disponible más reciente |
# | Balance Vida Trabajo 🧘 | Employees working very long hours | Empleados que trabajan muchas horas | Porcentaje | Porcentaje de empleados que trabajan más de cincuenta horas a la semana en promedio, año disponible más reciente |
# |  | Time devoted to leisure and personal care | Tiempo destinado al ocio y el cuidado personal | Horas | Número promedio de minutos al día dedicados al ocio y el cuidado personal, incluidos el sueño y la alimentación |

# %%
bli_df = pd.read_csv("./resources/dataset.csv")
bli_df.head(5)
# Out:
#      Country  Air pollution  Dwellings without basic facilities  \
# 0  Australia            5.0                                 NaN
# 1    Austria           16.0                                 0.9
# 2    Belgium           15.0                                 1.9
# 3     Brazil           10.0                                 6.7
# 4     Canada            7.0                                 0.2
#
#    Educational attainment  Employees working very long hours  Employment rate  \
# 0               81.000000                          12.840000        73.000000
# 1               85.000000                           6.590000        72.000000
# 2               77.000000                           4.703333        63.333333
# 3               49.000000                           7.006667        61.000000
# 4               91.333333                           3.673333        73.333333
#
#    Feeling safe walking alone at night  Homicide rate  \
# ...

# %% [markdown]
# ### Dataset de Temperaturas Globales
#
# ![wbg_climate](./resources/wbg_climate.png)
#
#
# https://climateknowledgeportal.worldbank.org/download-data

# %%
temp_df = pd.read_csv("./resources/temperature.csv")
temp_df.head(3)
# Out:
#    Temperature  Year Month      Country ISO3
# 0     -0.03110  1991   Jan  Afghanistan  AFG
# 1      1.43654  1991   Feb  Afghanistan  AFG
# 2      6.88685  1991   Mar  Afghanistan  AFG

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Multi-Índice

# %%
dataset_original = pd.read_csv('./resources/bli_original.csv')
dataset_original.head(5)
# Out:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value  Flag Codes  Flags
# ...

# %%
dataset_original.head(10).loc[:, ['Country', 'Unit', 'Indicator', 'Value']]
# Out:
#           Country        Unit                 Indicator  Value
# 0       Australia  Percentage  Labour market insecurity    5.4
# 1         Austria  Percentage  Labour market insecurity    3.5
# 2         Belgium  Percentage  Labour market insecurity    3.7
# 3          Canada  Percentage  Labour market insecurity    6.0
# 4  Czech Republic  Percentage  Labour market insecurity    3.1
# 5         Denmark  Percentage  Labour market insecurity    4.2
# 6         Finland  Percentage  Labour market insecurity    3.9
# 7          France  Percentage  Labour market insecurity    7.6
# 8         Germany  Percentage  Labour market insecurity    2.7
# 9          Greece  Percentage  Labour market insecurity   29.8

# %%
dataset_multindex = pd.pivot_table(dataset_original,
                                   index=['Country'],
                                   columns=['Unit', 'Indicator'],
                                   values='Value')
dataset_multindex.head(5)
# Out:
# Unit          Average score                                                    \
# Indicator Life satisfaction Stakeholder engagement for developing regulations
# Country
# Australia             7.350                                               2.7
# Austria               7.225                                               1.3
# Belgium               7.000                                               2.0
# Brazil                6.400                                               2.2
# Canada                7.425                                               2.9
#
# Unit                                                         Hours  \
# Indicator Student skills Time devoted to leisure and personal care
# Country
# Australia          411.2                                 14.350000
# Austria            492.8                                 14.530000
# Belgium            503.8                                 15.663333
# ...

# %% [markdown]
# > **Pregunta**: ¿Qué otro índice (exterior) para las filas podría haber sido interesante de agregar?

# %%
dataset_multindex.shape
# Out:
# (41, 24)

# %%
dataset_multindex.head(3)
# Out:
# Unit          Average score                                                    \
# Indicator Life satisfaction Stakeholder engagement for developing regulations
# Country
# Australia             7.350                                               2.7
# Austria               7.225                                               1.3
# Belgium               7.000                                               2.0
#
# Unit                                                         Hours  \
# Indicator Student skills Time devoted to leisure and personal care
# Country
# Australia          411.2                                 14.350000
# Austria            492.8                                 14.530000
# Belgium            503.8                                 15.663333
#
# Unit      Micrograms per cubic metre                         Percentage  \
# Indicator              Air pollution Dwellings without basic facilities
# Country
# ...

# %%
dataset_multindex.index
# Out:
# Index(['Australia', 'Austria', 'Belgium', 'Brazil', 'Canada', 'Chile',
#        'Colombia', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy',
#        'Japan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Mexico',
#        'Netherlands', 'New Zealand', 'Norway', 'OECD - Total', 'Poland',
#        'Portugal', 'Russia', 'Slovak Republic', 'Slovenia', 'South Africa',
#        'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Kingdom',
#        'United States'],
#       dtype='object', name='Country')

# %%
dataset_multindex.columns.values
# Out:
# array([('Average score', 'Life satisfaction'),
#        ('Average score', 'Stakeholder engagement for developing regulations'),
#        ('Average score', 'Student skills'),
#        ('Hours', 'Time devoted to leisure and personal care'),
#        ('Micrograms per cubic metre', 'Air pollution'),
#        ('Percentage', 'Dwellings without basic facilities'),
#        ('Percentage', 'Educational attainment'),
#        ('Percentage', 'Employees working very long hours'),
#        ('Percentage', 'Employment rate'),
#        ('Percentage', 'Feeling safe walking alone at night'),
#        ('Percentage', 'Housing expenditure'),
#        ('Percentage', 'Labour market insecurity'),
#        ('Percentage', 'Long-term unemployment rate'),
#        ('Percentage', 'Quality of support network'),
#        ('Percentage', 'Self-reported health'),
#        ('Percentage', 'Voter turnout'), ('Percentage', 'Water quality'),
#        ('Ratio', 'Homicide rate'), ('Ratio', 'Rooms per person'),
# ...

# %%
dataset_multindex.columns.get_level_values(0)
# Out:
# Index(['Average score', 'Average score', 'Average score', 'Hours',
#        'Micrograms per cubic metre', 'Percentage', 'Percentage', 'Percentage',
#        'Percentage', 'Percentage', 'Percentage', 'Percentage', 'Percentage',
#        'Percentage', 'Percentage', 'Percentage', 'Percentage', 'Ratio',
#        'Ratio', 'US Dollar', 'US Dollar', 'US Dollar', 'Years', 'Years'],
#       dtype='object', name='Unit')

# %%
dataset_multindex.columns.get_level_values(1)
# Out:
# Index(['Life satisfaction',
#        'Stakeholder engagement for developing regulations', 'Student skills',
#        'Time devoted to leisure and personal care', 'Air pollution',
#        'Dwellings without basic facilities', 'Educational attainment',
#        'Employees working very long hours', 'Employment rate',
#        'Feeling safe walking alone at night', 'Housing expenditure',
#        'Labour market insecurity', 'Long-term unemployment rate',
#        'Quality of support network', 'Self-reported health', 'Voter turnout',
#        'Water quality', 'Homicide rate', 'Rooms per person',
#        'Household net adjusted disposable income', 'Household net wealth',
#        'Personal earnings', 'Life expectancy', 'Years in education'],
#       dtype='object', name='Indicator')

# %% [markdown]
# > **Ejercicio ✏️**: Seleccionar la fila que contiene a Chile

# %%
dataset_multindex.loc[['Chile'],:]
# Out:
# Unit          Average score                                                    \
# Indicator Life satisfaction Stakeholder engagement for developing regulations
# Country
# Chile                  6.48                                               1.3
#
# Unit                                                         Hours  \
# Indicator Student skills Time devoted to leisure and personal care
# Country
# Chile              443.8                                       NaN
#
# Unit      Micrograms per cubic metre                         Percentage  \
# Indicator              Air pollution Dwellings without basic facilities
# Country
# Chile                           16.0                                9.4
#
# Unit                                                                \
# Indicator Educational attainment Employees working very long hours
# Country
# Chile                       65.0                          9.316667
#
# ...

# %% [markdown]
# > **Ejercicio ✏️**: Seleccionar las columnas de los indicadores basados en Porcentajes.

# %%
dataset_multindex.loc[:, 'Percentage']
# Out:
# Indicator        Dwellings without basic facilities  Educational attainment  \
# Country
# Australia                                       NaN               81.000000
# Austria                                         0.9               85.000000
# Belgium                                         1.9               77.000000
# Brazil                                          6.7               49.000000
# Canada                                          0.2               91.333333
# Chile                                           9.4               65.000000
# Colombia                                       23.9               54.000000
# Czech Republic                                  0.7               93.666667
# Denmark                                         0.5               81.000000
# Estonia                                         7.0               88.666667
# Finland                                         0.5               88.000000
# ...

# %%
dataset_multindex.loc[['Chile', 'Colombia', 'Brazil', 'Mexico'], 'Percentage']
# Out:
# Indicator  Dwellings without basic facilities  Educational attainment  \
# Country
# Chile                                     9.4               65.000000
# Colombia                                 23.9               54.000000
# Brazil                                    6.7               49.000000
# Mexico                                   25.5               37.666667
#
# Indicator  Employees working very long hours  Employment rate  \
# Country
# Chile                               9.316667        62.666667
# Colombia                           26.006667        67.000000
# Brazil                              7.006667        61.000000
# Mexico                             27.280000        61.666667
#
# Indicator  Feeling safe walking alone at night  Housing expenditure  \
# Country
# Chile                                48.000000                 18.0
# Colombia                             44.566667                 17.0
# ...

# %%
dataset_multindex.head(5)
# Out:
# Unit          Average score                                                    \
# Indicator Life satisfaction Stakeholder engagement for developing regulations
# Country
# Australia             7.350                                               2.7
# Austria               7.225                                               1.3
# Belgium               7.000                                               2.0
# Brazil                6.400                                               2.2
# Canada                7.425                                               2.9
#
# Unit                                                         Hours  \
# Indicator Student skills Time devoted to leisure and personal care
# Country
# Australia          411.2                                 14.350000
# Austria            492.8                                 14.530000
# Belgium            503.8                                 15.663333
# ...

# %%
dataset_multindex.loc[:, ('Percentage', 'Employment rate')]
# Out:
# Country
# Australia          73.000000
# Austria            72.000000
# Belgium            63.333333
# Brazil             61.000000
# Canada             73.333333
# Chile              62.666667
# Colombia           67.000000
# Czech Republic     73.666667
# Denmark            74.000000
# Estonia            74.000000
# Finland            70.333333
# France             65.333333
# Germany            75.333333
# Greece             53.333333
# Hungary            68.000000
# Iceland            85.666667
# Ireland            67.333333
# Israel             69.000000
# Italy              58.000000
# Japan              75.000000
# Korea              66.666667
# Latvia             70.000000
# Lithuania          70.333333
# Luxembourg         66.333333
# Mexico             61.666667
# Netherlands        75.666667
# New Zealand        77.000000
# Norway             74.000000
# OECD - Total       68.000000
# Poland             66.000000
# Portugal           68.000000
# ...

# %%
dataset_multindex.loc[:, ('Percentage', 'Housing expenditure')]
# Out:
# Country
# Australia          20.0
# Austria            21.0
# Belgium            21.0
# Brazil              NaN
# Canada             22.0
# Chile              18.0
# Colombia           17.0
# Czech Republic     24.0
# Denmark            23.0
# Estonia            17.0
# Finland            23.0
# France             21.0
# Germany            20.0
# Greece             23.0
# Hungary            19.0
# Iceland            24.0
# Ireland            20.0
# Israel              NaN
# Italy              23.0
# Japan              22.0
# Korea              15.0
# Latvia             23.0
# Lithuania          19.0
# Luxembourg         21.0
# Mexico             20.0
# Netherlands        19.0
# New Zealand        26.0
# Norway             17.0
# OECD - Total       20.0
# Poland             22.0
# Portugal           21.0
# Russia             18.0
# Slovak Republic    23.0
# Slovenia           18.0
# South Africa       18.0
# Spain              21.0
# Sweden             19.0
# Switzerland        22.0
# ...

# %% [markdown]
# > **Pregunta**: ¿Cómo puedo solicitar `Housing expenditure` como `Employment rate` al mismo tiempo?

# %%
dataset_multindex.loc[:, [('Percentage', 'Housing expenditure'),
                          ('Percentage', 'Employment rate')]]
# Out:
# Unit                     Percentage
# Indicator       Housing expenditure Employment rate
# Country
# Australia                      20.0       73.000000
# Austria                        21.0       72.000000
# Belgium                        21.0       63.333333
# Brazil                          NaN       61.000000
# Canada                         22.0       73.333333
# Chile                          18.0       62.666667
# Colombia                       17.0       67.000000
# Czech Republic                 24.0       73.666667
# Denmark                        23.0       74.000000
# Estonia                        17.0       74.000000
# Finland                        23.0       70.333333
# France                         21.0       65.333333
# Germany                        20.0       75.333333
# Greece                         23.0       53.333333
# Hungary                        19.0       68.000000
# Iceland                        24.0       85.666667
# ...

# %% [markdown]
# ### IndexSlice

# %%
idx = pd.IndexSlice

dataset_multindex.loc[:, idx[
    'Percentage',
    ['Housing expenditure', 'Employees working very long hours']]]
# Out:
# Unit                     Percentage
# Indicator       Housing expenditure Employees working very long hours
# Country
# Australia                      20.0                         12.840000
# Austria                        21.0                          6.590000
# Belgium                        21.0                          4.703333
# Brazil                          NaN                          7.006667
# Canada                         22.0                          3.673333
# Chile                          18.0                          9.316667
# Colombia                       17.0                         26.006667
# Czech Republic                 24.0                          5.496667
# Denmark                        23.0                          2.316667
# Estonia                        17.0                          2.436667
# Finland                        23.0                          3.816667
# France                         21.0                          7.656667
# ...

# %%
idx = pd.IndexSlice

dataset_multindex.loc[:, idx[
    ['Hours', 'Percentage'],
    ['Time devoted to leisure and personal care', 'Employees working very long hours', 'Housing expenditure']]]
# Out:
# Unit                                                Hours  \
# Indicator       Time devoted to leisure and personal care
# Country
# Australia                                       14.350000
# Austria                                         14.530000
# Belgium                                         15.663333
# Brazil                                                NaN
# Canada                                          14.553333
# Chile                                                 NaN
# Colombia                                              NaN
# Czech Republic                                        NaN
# Denmark                                         15.873333
# Estonia                                         14.886667
# Finland                                         15.163333
# France                                          16.336667
# Germany                                         15.613333
# Greece                                                NaN
# ...

# %% [markdown]
# ### Descartar Índices

# %%
df_multiindex = dataset_multindex.loc[:, idx[
    ['Hours', 'Percentage'],
    ['Time devoted to leisure and personal care', 'Employees working very long hours', 'Housing expenditure']]]

df_multiindex.droplevel(level=0, axis=1)
# Out:
# Indicator        Time devoted to leisure and personal care  \
# Country
# Australia                                        14.350000
# Austria                                          14.530000
# Belgium                                          15.663333
# Brazil                                                 NaN
# Canada                                           14.553333
# Chile                                                  NaN
# Colombia                                               NaN
# Czech Republic                                         NaN
# Denmark                                          15.873333
# Estonia                                          14.886667
# Finland                                          15.163333
# France                                           16.336667
# Germany                                          15.613333
# Greece                                                 NaN
# Hungary                                                NaN
# ...

# %%
df_multiindex.droplevel(level=1, axis=1)
# Out:
# Unit                 Hours  Percentage  Percentage
# Country
# Australia        14.350000   12.840000        20.0
# Austria          14.530000    6.590000        21.0
# Belgium          15.663333    4.703333        21.0
# Brazil                 NaN    7.006667         NaN
# Canada           14.553333    3.673333        22.0
# Chile                  NaN    9.316667        18.0
# Colombia               NaN   26.006667        17.0
# Czech Republic         NaN    5.496667        24.0
# Denmark          15.873333    2.316667        23.0
# Estonia          14.886667    2.436667        17.0
# Finland          15.163333    3.816667        23.0
# France           16.336667    7.656667        21.0
# Germany          15.613333    4.196667        20.0
# Greece                 NaN    6.280000        23.0
# Hungary                NaN    2.976667        19.0
# Iceland                NaN   14.866667        24.0
# Ireland                NaN    5.260000        20.0
# ...

# %% [markdown]
# ## Strings
#
# Es común que los datasets incluyan por lo menos una columna que contiene texto. Por lo general, el texto no es utilizable tal como viene (desordenado y sucio) por lo que preprocesarlo antes de utilizarlo es una tarea que se debe dominar.
#
# Las `Series` de pandas implementan diversos métodos de procesamiento de string que permiten operar facilmente con estos. Por lo general, estos métodos son una réplica de los métodos originales de la clase built-in `string`.
#
# <img src='./resources/pets.jpg' alt='Mascotas' width=400/>

# %%
mascotas = [
    ('Perro',
     'El perro (Canis familiaris o Canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),1​2​3​ llamado perro doméstico o can,4​ y en algunos lugares coloquialmente llamado chucho,5​ tuso,6​ choco,7​ entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género Canis.8​9​ En el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10​11​ Su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. Posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. Su longevidad media es de diez a trece años,12​13​14​ dependiendo de la raza. '
     ),
    ('Gato',
     'El gato doméstico1​2​ (Felis silvestris catus), llamado popularmente gato, y de forma coloquial minino,3​ michino,4​ michi,5​ micho,6​ mizo,7​ miz,8​ morroño9​ o morrongo,10​ entre otros nombres, es un mamífero carnívoro de la familia Felidae. Es una subespecie domesticada por la convivencia con el ser humano. '
     ),
]
mascotas_df = pd.DataFrame(mascotas, columns=['nombre', 'descripción'])
mascotas_df
# Out:
#   nombre  \
# 0  Perro
# 1   Gato
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      descripción
# ...

# %%
desc_perro = mascotas[0][1]
desc_perro
# Out:
# 'El perro (Canis familiaris o Canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),1\u200b2\u200b3\u200b llamado perro doméstico o can,4\u200b y en algunos lugares coloquialmente llamado chucho,5\u200b tuso,6\u200b choco,7\u200b entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género Canis.8\u200b9\u200b En el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10\u200b11\u200b Su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. Posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. Su longevidad media es de diez a trece años,12\u200b13\u200b14\u200b dependiendo de la raza. '

# %% [markdown]
# ### Métodos de la Clase String
#
# Como se dijo anteriormente, la mayoría de los métodos para string que implementa pandas sobre las `Series` son una réplica de los métodos implementados por la clase `String`.
#
# A continuación veremos un par de ejemplos de los métodos de strings y como utilizar estos métodos sobre una serie.

# %%
len(desc_perro)
# Out:
# 749

# %%
desc_perro.lower()
# Out:
# 'el perro (canis familiaris o canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),1\u200b2\u200b3\u200b llamado perro doméstico o can,4\u200b y en algunos lugares coloquialmente llamado chucho,5\u200b tuso,6\u200b choco,7\u200b entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género canis.8\u200b9\u200b en el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10\u200b11\u200b su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. su longevidad media es de diez a trece años,12\u200b13\u200b14\u200b dependiendo de la raza. '

# %%
desc_perro.upper()
# Out:
# 'EL PERRO (CANIS FAMILIARIS O CANIS LUPUS FAMILIARIS, DEPENDIENDO DE SI SE LO CONSIDERA UNA ESPECIE POR DERECHO PROPIO O UNA SUBESPECIE DEL LOBO),1\u200b2\u200b3\u200b LLAMADO PERRO DOMÉSTICO O CAN,4\u200b Y EN ALGUNOS LUGARES COLOQUIALMENTE LLAMADO CHUCHO,5\u200b TUSO,6\u200b CHOCO,7\u200b ENTRE OTROS; ES UN MAMÍFERO CARNÍVORO DE LA FAMILIA DE LOS CÁNIDOS, QUE CONSTITUYE UNA ESPECIE DEL GÉNERO CANIS.8\u200b9\u200b EN EL 2013, LA POBLACIÓN MUNDIAL ESTIMADA DE PERROS ESTABA ENTRE SETECIENTOS MILLONES Y NOVECIENTOS OCHENTA Y SIETE MILLONES.10\u200b11\u200b SU TAMAÑO (O TALLA), SU FORMA Y SU PELAJE ES MUY DIVERSO, SEGÚN LA RAZA. POSEE UN OÍDO Y UN OLFATO MUY DESARROLLADOS, Y ESTE ÚLTIMO ES SU PRINCIPAL ÓRGANO SENSORIAL. SU LONGEVIDAD MEDIA ES DE DIEZ A TRECE AÑOS,12\u200b13\u200b14\u200b DEPENDIENDO DE LA RAZA. '

# %%
desc_perro.title()
# Out:
# 'El Perro (Canis Familiaris O Canis Lupus Familiaris, Dependiendo De Si Se Lo Considera Una Especie Por Derecho Propio O Una Subespecie Del Lobo),1\u200b2\u200b3\u200b Llamado Perro Doméstico O Can,4\u200b Y En Algunos Lugares Coloquialmente Llamado Chucho,5\u200b Tuso,6\u200b Choco,7\u200b Entre Otros; Es Un Mamífero Carnívoro De La Familia De Los Cánidos, Que Constituye Una Especie Del Género Canis.8\u200b9\u200b En El 2013, La Población Mundial Estimada De Perros Estaba Entre Setecientos Millones Y Novecientos Ochenta Y Siete Millones.10\u200b11\u200b Su Tamaño (O Talla), Su Forma Y Su Pelaje Es Muy Diverso, Según La Raza. Posee Un Oído Y Un Olfato Muy Desarrollados, Y Este Último Es Su Principal Órgano Sensorial. Su Longevidad Media Es De Diez A Trece Años,12\u200b13\u200b14\u200b Dependiendo De La Raza. '

# %%
desc_perro.split(' ')
# Out:
# ['El',
#  'perro',
#  '(Canis',
#  'familiaris',
#  'o',
#  'Canis',
#  'lupus',
#  'familiaris,',
#  'dependiendo',
#  'de',
#  'si',
#  'se',
#  'lo',
#  'considera',
#  'una',
#  'especie',
#  'por',
#  'derecho',
#  'propio',
#  'o',
#  'una',
#  'subespecie',
#  'del',
#  'lobo),1\u200b2\u200b3\u200b',
#  'llamado',
#  'perro',
#  'doméstico',
#  'o',
#  'can,4\u200b',
#  'y',
#  'en',
#  'algunos',
#  'lugares',
#  'coloquialmente',
#  'llamado',
#  'chucho,5\u200b',
#  'tuso,6\u200b',
#  'choco,7\u200b',
#  'entre',
#  'otros;',
#  'es',
#  'un',
#  'mamífero',
#  'carnívoro',
#  'de',
#  'la',
#  'familia',
#  'de',
#  'los',
#  'cánidos,',
#  'que',
#  'constituye',
#  'una',
#  'especie',
#  'del',
#  'género',
#  'Canis.8\u200b9\u200b',
#  'En',
#  'el',
#  '2013,',
#  'la',
#  'población',
#  'mundial',
#  'estimada',
#  'de',
#  'perros',
#  'estaba',
#  'entre',
#  'setecientos',
#  'millones',
#  'y',
#  'novecientos',
#  'ochenta',
#  'y',
#  'siete',
# ...

# %%
'-'.join(['Este', 'string', '(ya no)', 'esta', 'separado'])
# Out:
# 'Este-string-(ya no)-esta-separado'

# %%
'perro' in desc_perro
# Out:
# True

# %%
'gato' in desc_perro
# Out:
# False

# %% [markdown]
# ### Strings En Las Series

# %%
mascotas_df['descripción']
# Out:
# 0    El perro (Canis familiaris o Canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),1​2​3​ llamado perro doméstico o can,4​ y en algunos lugares coloquialmente llamado chucho,5​ tuso,6​ choco,7​ entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género Canis.8​9​ En el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10​11​ Su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. Posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. Su longevidad media es de diez a trece años,12​13​14​ dependiendo de la raza.
# ...

# %% [markdown]
# #### Len, Lower, Upper, Title y Capitalize

# %%
mascotas_df['descripción'].str.len()
# Out:
# 0    749
# 1    312
# Name: descripción, dtype: int64

# %%
mascotas_df['descripción'].str.lower()
# Out:
# 0    el perro (canis familiaris o canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),1​2​3​ llamado perro doméstico o can,4​ y en algunos lugares coloquialmente llamado chucho,5​ tuso,6​ choco,7​ entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género canis.8​9​ en el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10​11​ su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. su longevidad media es de diez a trece años,12​13​14​ dependiendo de la raza.
# ...

# %%
mascotas_df['descripción'].str.upper()
# Out:
# 0    EL PERRO (CANIS FAMILIARIS O CANIS LUPUS FAMILIARIS, DEPENDIENDO DE SI SE LO CONSIDERA UNA ESPECIE POR DERECHO PROPIO O UNA SUBESPECIE DEL LOBO),1​2​3​ LLAMADO PERRO DOMÉSTICO O CAN,4​ Y EN ALGUNOS LUGARES COLOQUIALMENTE LLAMADO CHUCHO,5​ TUSO,6​ CHOCO,7​ ENTRE OTROS; ES UN MAMÍFERO CARNÍVORO DE LA FAMILIA DE LOS CÁNIDOS, QUE CONSTITUYE UNA ESPECIE DEL GÉNERO CANIS.8​9​ EN EL 2013, LA POBLACIÓN MUNDIAL ESTIMADA DE PERROS ESTABA ENTRE SETECIENTOS MILLONES Y NOVECIENTOS OCHENTA Y SIETE MILLONES.10​11​ SU TAMAÑO (O TALLA), SU FORMA Y SU PELAJE ES MUY DIVERSO, SEGÚN LA RAZA. POSEE UN OÍDO Y UN OLFATO MUY DESARROLLADOS, Y ESTE ÚLTIMO ES SU PRINCIPAL ÓRGANO SENSORIAL. SU LONGEVIDAD MEDIA ES DE DIEZ A TRECE AÑOS,12​13​14​ DEPENDIENDO DE LA RAZA.
# ...

# %%
mascotas_df['descripción'].str.title()
# Out:
# 0    El Perro (Canis Familiaris O Canis Lupus Familiaris, Dependiendo De Si Se Lo Considera Una Especie Por Derecho Propio O Una Subespecie Del Lobo),1​2​3​ Llamado Perro Doméstico O Can,4​ Y En Algunos Lugares Coloquialmente Llamado Chucho,5​ Tuso,6​ Choco,7​ Entre Otros; Es Un Mamífero Carnívoro De La Familia De Los Cánidos, Que Constituye Una Especie Del Género Canis.8​9​ En El 2013, La Población Mundial Estimada De Perros Estaba Entre Setecientos Millones Y Novecientos Ochenta Y Siete Millones.10​11​ Su Tamaño (O Talla), Su Forma Y Su Pelaje Es Muy Diverso, Según La Raza. Posee Un Oído Y Un Olfato Muy Desarrollados, Y Este Último Es Su Principal Órgano Sensorial. Su Longevidad Media Es De Diez A Trece Años,12​13​14​ Dependiendo De La Raza.
# ...

# %%
mascotas_df['descripción'].str.capitalize()
# Out:
# 0    El perro (canis familiaris o canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),1​2​3​ llamado perro doméstico o can,4​ y en algunos lugares coloquialmente llamado chucho,5​ tuso,6​ choco,7​ entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género canis.8​9​ en el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10​11​ su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. su longevidad media es de diez a trece años,12​13​14​ dependiendo de la raza.
# ...

# %% [markdown]
# #### Contains, Split y Join

# %%
mascotas_df['descripción'].str.contains('perro')
# Out:
# 0     True
# 1    False
# Name: descripción, dtype: bool

# %%
mascotas_df['descripción'].str.contains('gato')
# Out:
# 0    False
# 1     True
# Name: descripción, dtype: bool

# %%
mascotas_df['descripción'].str.split(' ')
# Out:
# 0    [El, perro, (Canis, familiaris, o, Canis, lupus, familiaris,, dependiendo, de, si, se, lo, considera, una, especie, por, derecho, propio, o, una, subespecie, del, lobo),1​2​3​, llamado, perro, doméstico, o, can,4​, y, en, algunos, lugares, coloquialmente, llamado, chucho,5​, tuso,6​, choco,7​, entre, otros;, es, un, mamífero, carnívoro, de, la, familia, de, los, cánidos,, que, constituye, una, especie, del, género, Canis.8​9​, En, el, 2013,, la, población, mundial, estimada, de, perros, estaba, entre, setecientos, millones, y, novecientos, ochenta, y, siete, millones.10​11​, Su, tamaño, (o, talla),, su, forma, y, su, pelaje, es, muy, diverso,, según, la, raza., Posee, un, oído, y, un, olfato, muy, desarrollados,, y, ...]
# ...

# %%
mascotas_df['descripción'].str.split(' ').str.join('|')
# Out:
# 0    El|perro|(Canis|familiaris|o|Canis|lupus|familiaris,|dependiendo|de|si|se|lo|considera|una|especie|por|derecho|propio|o|una|subespecie|del|lobo),1​2​3​|llamado|perro|doméstico|o|can,4​|y|en|algunos|lugares|coloquialmente|llamado|chucho,5​|tuso,6​|choco,7​|entre|otros;|es|un|mamífero|carnívoro|de|la|familia|de|los|cánidos,|que|constituye|una|especie|del|género|Canis.8​9​|En|el|2013,|la|población|mundial|estimada|de|perros|estaba|entre|setecientos|millones|y|novecientos|ochenta|y|siete|millones.10​11​|Su|tamaño|(o|talla),|su|forma|y|su|pelaje|es|muy|diverso,|según|la|raza.|Posee|un|oído|y|un|olfato|muy|desarrollados,|y|este|último|es|su|principal|órgano|sensorial.|Su|longevidad|media|es|de|diez|a|trece|años,12​13​14​|dependiendo|de|la|raza.|
# ...

# %% [markdown]
# #### Replace

# %%
mascotas_df['descripción'].str.replace('(', '', regex=False).str.replace(
    ')', '', regex=False)
# Out:
# 0    El perro Canis familiaris o Canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo,1​2​3​ llamado perro doméstico o can,4​ y en algunos lugares coloquialmente llamado chucho,5​ tuso,6​ choco,7​ entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género Canis.8​9​ En el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10​11​ Su tamaño o talla, su forma y su pelaje es muy diverso, según la raza. Posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. Su longevidad media es de diez a trece años,12​13​14​ dependiendo de la raza.
# ...

# %% [markdown]
# ##### Expresiones Regulares
#
# > Según [`re` de `python`](https://docs.python.org/3/library/re.html): *A regular expression (or RE) specifies a set of strings that matches it; the functions in this module let you check if a particular string matches a given regular expression (or if a given regular expression matches a particular string, which comes down to the same thing).*
#
#
# - https://www.programiz.com/python-programming/regex
#
# - https://regex101.com/

# %%
mascotas_df['descripción'].str.replace('\(|\)|,', ' ', regex=True)
# Out:
# 0    El perro  Canis familiaris o Canis lupus familiaris  dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo  1​2​3​ llamado perro doméstico o can 4​ y en algunos lugares coloquialmente llamado chucho 5​ tuso 6​ choco 7​ entre otros; es un mamífero carnívoro de la familia de los cánidos  que constituye una especie del género Canis.8​9​ En el 2013  la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10​11​ Su tamaño  o talla   su forma y su pelaje es muy diverso  según la raza. Posee un oído y un olfato muy desarrollados  y este último es su principal órgano sensorial. Su longevidad media es de diez a trece años 12​13​14​ dependiendo de la raza.
# ...

# %%
mascotas_df['descripción'].str.replace('\d{1,3}', '', regex=True)
# Out:
# 0    El perro (Canis familiaris o Canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),​​​ llamado perro doméstico o can,​ y en algunos lugares coloquialmente llamado chucho,​ tuso,​ choco,​ entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género Canis.​​ En el , la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.​​ Su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. Posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. Su longevidad media es de diez a trece años,​​​ dependiendo de la raza.
# ...

# %% [markdown]
# ### Apply
#
# Aplica una función sobre una serie (o sobre las filas o columnas de un DataFrame)

# %%
mascotas_df['descripción'].apply(lambda x: 'gato' in x)
# Out:
# 0    False
# 1     True
# Name: descripción, dtype: bool

# %%
import unicodedata

def strip_accents_ascii(s):
    """Transform accentuated unicode symbols into ascii or nothing
    Warning: this solution is only suited for languages that have a direct
    transliteration to ASCII symbols.
    See also
    --------
    strip_accents_unicode
        Remove accentuated char for any unicode symbol.
    """
    nkfd_form = unicodedata.normalize('NFKD', s)
    return nkfd_form.encode('ASCII', 'ignore').decode('ASCII')

# %%
mascotas_df['descripción'].apply(strip_accents_ascii)
# Out:
# 0    El perro (Canis familiaris o Canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),123 llamado perro domestico o can,4 y en algunos lugares coloquialmente llamado chucho,5 tuso,6 choco,7 entre otros; es un mamifero carnivoro de la familia de los canidos, que constituye una especie del genero Canis.89 En el 2013, la poblacion mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.1011 Su tamano (o talla), su forma y su pelaje es muy diverso, segun la raza. Posee un oido y un olfato muy desarrollados, y este ultimo es su principal organo sensorial. Su longevidad media es de diez a trece anos,121314 dependiendo de la raza.
# ...

# %% [markdown]
# Aplicación sobre DataFrames:

# %%
mascotas_df
# Out:
#   nombre  \
# 0  Perro
# 1   Gato
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      descripción
# ...

# %%
mascotas_df.apply(lambda x: x['nombre'] + ' - ' + x['descripción'], axis=1)
# Out:
# 0    Perro - El perro (Canis familiaris o Canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),1​2​3​ llamado perro doméstico o can,4​ y en algunos lugares coloquialmente llamado chucho,5​ tuso,6​ choco,7​ entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género Canis.8​9​ En el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10​11​ Su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. Posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. Su longevidad media es de diez a trece años,12​13​14​ dependiendo de la raza.
# ...

# %%
mascotas_df.apply(lambda x: x.sum(), axis=0)
# Out:
# nombre                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# ...

# %% [markdown]
# #### Preprocesamiento Completo

# %%
desc_perro
# Out:
# 'El perro (Canis familiaris o Canis lupus familiaris, dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo),1\u200b2\u200b3\u200b llamado perro doméstico o can,4\u200b y en algunos lugares coloquialmente llamado chucho,5\u200b tuso,6\u200b choco,7\u200b entre otros; es un mamífero carnívoro de la familia de los cánidos, que constituye una especie del género Canis.8\u200b9\u200b En el 2013, la población mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones.10\u200b11\u200b Su tamaño (o talla), su forma y su pelaje es muy diverso, según la raza. Posee un oído y un olfato muy desarrollados, y este último es su principal órgano sensorial. Su longevidad media es de diez a trece años,12\u200b13\u200b14\u200b dependiendo de la raza. '

# %%
(mascotas_df['descripción']
     .apply(lambda x: strip_accents_ascii(x))
     .str.replace('\(|\)|,|\d{1,3}|;|\.', ' ',regex=True)
     .str.replace(r'\s+', ' ', regex=True)
     .str.strip()
     .str.lower())
# Out:
# 0    el perro canis familiaris o canis lupus familiaris dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo llamado perro domestico o can y en algunos lugares coloquialmente llamado chucho tuso choco entre otros es un mamifero carnivoro de la familia de los canidos que constituye una especie del genero canis en el la poblacion mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones su tamano o talla su forma y su pelaje es muy diverso segun la raza posee un oido y un olfato muy desarrollados y este ultimo es su principal organo sensorial su longevidad media es de diez a trece anos dependiendo de la raza
# ...

# %% [markdown]
# #### Concatenación

# %%
desc_limpia = (
    mascotas_df['descripción']
     .apply(lambda x: strip_accents_ascii(x))
     .str.replace('\(|\)|,|\d{1,3}|;|\.', ' ',regex=True)
     .str.replace(r'\s+', ' ', regex=True)
     .str.strip()
     .str.lower()
)

desc_limpia.str.cat(sep="|")
# Out:
# 'el perro canis familiaris o canis lupus familiaris dependiendo de si se lo considera una especie por derecho propio o una subespecie del lobo llamado perro domestico o can y en algunos lugares coloquialmente llamado chucho tuso choco entre otros es un mamifero carnivoro de la familia de los canidos que constituye una especie del genero canis en el la poblacion mundial estimada de perros estaba entre setecientos millones y novecientos ochenta y siete millones su tamano o talla su forma y su pelaje es muy diverso segun la raza posee un oido y un olfato muy desarrollados y este ultimo es su principal organo sensorial su longevidad media es de diez a trece anos dependiendo de la raza|el gato domestico felis silvestris catus llamado popularmente gato y de forma coloquial minino michino michi micho mizo miz morrono o morrongo entre otros nombres es un mamifero carnivoro de la familia felidae es una subespecie domesticada por la convivencia con el ser humano'
