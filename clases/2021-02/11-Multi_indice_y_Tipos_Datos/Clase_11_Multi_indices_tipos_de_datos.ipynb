# %% [markdown]
# # Clase 9: Multi-Indices y Tipos de Datos
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# **Profesor: Pablo Badilla**
#
# ## Objetivos de la Clase
#
# - Comprender como unir distintas fuentes de datos a partir de `concatenaciones` y `merge`.
#
# ### Roadmap
#
#
# **Unidad 2: Manejo de Datos con Pandas y AED**
#
# - [X] Introducción a pandas: DataFrames, Series, Operaciones básicas y Filtrado.
# - [X] Agregaciones.
# - [X] Visualizaciones interactivas usando Plotly.
# - [X] Concatenaciones y Merge de Dataframes.
# - [ ] Multi-índices y Trabajo con strings y datos temporales, categóricos y ordinales en Pandas.
# - [ ] Análisis exploratorio de Datos (AED).

# %% [markdown]
# ## Datasets de Hoy
#
# ### Índices para una Vida Mejor
#
# Nuevamente, seguiremos usando los datos de índices para una Vida Mejor de la OECD:
#
#
# <img src="./resources/oecd.png" alt="OECD Better life index"/>
#
#
# http://www.oecdbetterlifeindex.org/
#
# https://stats.oecd.org/index.aspx?DataSetCode=BLI
#
# Son 11 temas considerados como esenciales para el bienestar de la población. Cada crierio contiene uno o mas indicadores
#
# | Tema | Indicador (Inglés) | Indicador (Español) | Unidad | Descripción |
# |---|---|---|---|---|
# | Vivienda 🏠 | Dwellings without basic facilities | Vivienda con Instalaciones Básicas | Porcentaje | Porcentaje de personas con inodoros de agua corriente dentro del hogar, año disponible más reciente |
# |  | Housing expenditure | Gastos en Vivienda | Porcentaje | Proporción de costos de vivienda en el ingreso neto ajustado de las familias, año disponible más reciente |
# |  | Rooms per person | Habitaciones por Persona | Ratio | Número promedio de habitaciones compartidas por persona en una vivienda, año disponible más reciente |
# | Ingresos 💰 | Household net adjusted disposable income | Ingreso Familiar Disponible | US Dollar | Cantidad promedio de dinero que una familia gana al año, después de impuestos, año disponible más reciente |
# |  | Household net wealth | Patrimonio Neto Familiar | US Dollar | Valor total promedio de los activos financieros de una familia (ahorros, acciones) menos sus pasivos (créditos), año disponible más reciente |
# | Empleo ⚙️ | Labour market insecurity | Seguridad en el Empleo | Porcentaje | Pérdida esperada de ingresos cuando alguien queda desempleado, año disponible más reciente |
# |  | Employment rate | Tasa de Empleo | Porcentaje | Porcentaje de personas, de 15 a 64 años de edad, actualmente con empleo remunerado, año disponible más reciente |
# |  | Long-term unemployment rate | Tasa de Empleo a Largo Plazo | Porcentaje | Porcentaje de personas, de 15 a 64 años de edad, que no trabajan pero que han buscado empleo activamente durante más de un año, año disponible más reciente |
# |  | Personal earnings | Ingresos Personales | US Dollar | Ingresos anuales promedio por empleado de tiempo completo, año disponible más reciente |
# | Comunidad 🧑‍🤝‍🧑   | Quality of support network  | Calidad del Apoyo Social | Porcentaje | Porcentaje de personas con amigos o parientes en quienes confiar en caso de necesidad |
# | Educación 📚 | Educational attainment | Nivel de Educación | Porcentaje | Porcentaje de personas, de 25 a 64 años de edad, graduadas por lo menos de educación media superior, año disponible más reciente |
# |  | Student skills | Competencias de estudiantes en matemáticas, lectura y ciencias | Puntaje promedio | Desempeño promedio de estudiantes de 15 años de edad, según PISA (Programa para la Evaluación Internacional de Estudiantes) |
# |  | Years in education  | Nivel de educación | Años | Duración promedio de la educación formal en la que un niño de cinco años de edad puede esperar matricularse durante su vida |
# | Medio Ambiente 🌳 | Air pollution | Contaminación del Aire | Microgramos por metro cúbico | Concentración promedio de partículas (PM2.5) en ciudades con poblaciones mayores de 100,000 personas, medida en microgramos por metro cúbico, año disponible más reciente |
# |  | Water quality | Calidad del Agua | Porcentaje | Porcentaje de personas que informan estar satisfechas con la calidad del agua local |
# | Compromiso Cívico 🗳️  | Stakeholder engagement for developing regulations | Participación de los interesados en la elaboración de regulaciones | Puntaje promedio | Nivel de transparencia gubernamental al preparar las regulaciones, año disponible más reciente |
# |  | Voter turnout | Participación electoral | Porcentaje | Porcentaje de votantes registrados que votaron durante las elecciones recientes, año disponible más reciente |
# | Salud ⚕️ | Life expectancy | Esperanza de vida | Años | Número promedio de años que una persona puede esperar vivir, año disponible más reciente |
# |  | Self-reported health | Salud según informan las personas | Porcentaje | Porcentaje de personas que informan que su salud es «buena o muy buena», año disponible más reciente |
# | Satisfacción ✨ | Life satisfaction | Satisfacción ante la vida | Puntaje promedio | Autoevaluación promedio de satisfacción ante la vida, en una escala de 0 a 10 |
# | Seguridad 🌃 | Feeling safe walking alone at night | Sentimiento de seguridad al caminar solos por la noche | Porcentaje | Porcentaje de personas que reportan sentirse seguras al caminar solas por la noche  |
# |  | Homicide rate | Tasa de homicidios | Ratio | Número promedio de homicidios reportados por 100,000 personas, año disponible más reciente |
# | Balance Vida Trabajo 🧘 | Employees working very long hours | Empleados que trabajan muchas horas | Porcentaje | Porcentaje de empleados que trabajan más de cincuenta horas a la semana en promedio, año disponible más reciente |
# |  | Time devoted to leisure and personal care | Tiempo destinado al ocio y el cuidado personal | Horas | Número promedio de minutos al día dedicados al ocio y el cuidado personal, incluidos el sueño y la alimentación |

# %% [markdown]
# ## Strings

# %% [markdown]
# ## Datos Temporales

# %% [markdown]
# ### Módulo Datetime
#
# Módulo built-in de python enfocado en manejar fechas y horas.

# %%
import datetime

# %% [markdown]
# #### Date
#
# Objeto que almacena día, mes y año.

# %%
date_object = datetime.date.today()
print(date_object)
# Out:
# 2021-09-27

# %% [markdown]
# #### Datetime
#
# Almacena segundos, minutos, hora, día, mes y año. También puede contener timezone.

# %%
datetime_object = datetime.datetime.now()
print(datetime_object)
# Out:
# 2021-09-27 15:39:50.662469

# %% [markdown]
# #### Instanciar nuevos Date y Datetimes

# %%
d = datetime.date(2021, 9, 9)
print(d)
# Out:
# 2021-09-09

# %%
print("Año:", d.year)
print("Mes:", d.month)
print("Día:", d.day)
# Out:
# Año: 2021
# Mes: 9
# Día: 9

# %%
d = datetime.datetime(2021, 4, 19, 10, 59, 55)
print(d)
# Out:
# 2021-04-19 10:59:55

# %%
print("Hora:", d.hour)
print("Minuto:", d.minute)
print("Segundo:", d.second)
print("Microsegundo:", d.microsecond)
# Out:
# Hora: 10
# Minuto: 59
# Segundo: 55
# Microsegundo: 0

# %% [markdown]
# Obviamente, estos objetos cuentan con las restricciones pertinentes

# %%
def imprimir_restricciones(a, m, d, h=0, mi=1, s=1):
    try:
        d = datetime.datetime(a, m, d, h, mi, s)
        return d
    except Exception as e:
        print(f"Error: {e}")

# %%
imprimir_restricciones(-1, 4, 19, 10, 59, 55)
# Out:
# Error: year -1 is out of range

# %%
imprimir_restricciones(9999, 4, 19, 10, 59, 55)
# Out:
# datetime.datetime(9999, 4, 19, 10, 59, 55)

# %% [markdown]
# Relacionado: https://es.wikipedia.org/wiki/Problema_del_a%C3%B1o_2000
#
#
# El problema del año 2000, fue un bug o error de software causado por la costumbre que habían adoptado los programadores de omitir la centuria en el año para el almacenamiento de fechas (generalmente para economizar memoria), asumiendo que el software solo funcionaría durante los años cuyos números comenzaran con 19XX

# %%
imprimir_restricciones(999999, 4, 19, 10, 59, 55)
# Out:
# Error: year 999999 is out of range

# %%
imprimir_restricciones(2020, 4, 19, 10, 60, 55)
# Out:
# Error: minute must be in 0..59

# %% [markdown]
# ¿Y los años bisiestos?

# %%
imprimir_restricciones(2020, 2, 29)
# Out:
# datetime.datetime(2020, 2, 29, 0, 1, 1)

# %%
imprimir_restricciones(2021, 2, 29)
# Out:
# Error: day is out of range for month

# %% [markdown]
# ##### Desde timestamp
#
# `A Unix timestamp is the number of seconds between a particular date and January 1, 1970 at UTC.`

# %%
timestamp = datetime.date.fromtimestamp(1326244364)
print("Date =", timestamp)
# Out:
# Date = 2012-01-10

# %% [markdown]
# > **Pregunta ❓**: ¿Podemos sumar o restar fechas?

# %%
delta = datetime.datetime(1, 1, 1)
delta
# Out:
# datetime.datetime(1, 1, 1, 0, 0)

# %%
d + delta
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10594/1477006583.py in <module>
# ----> 1 d + delta
#
# TypeError: unsupported operand type(s) for +: 'datetime.datetime' and 'datetime.datetime'

# %% [markdown]
# #### TimeDelta
#
# Permide sumar semanas, días, horas, etc... a objetos `date` y `datetime`.

# %%
d
# Out:
# datetime.datetime(2021, 4, 19, 10, 59, 55)

# %%
from datetime import timedelta

t1 = timedelta(weeks=2)
t1
# Out:
# datetime.timedelta(days=14)

# %%
d + t1
# Out:
# datetime.datetime(2021, 5, 3, 10, 59, 55)

# %% [markdown]
# ¿Y tiempos negativos?

# %%
t2 = timedelta(minutes=-1)

# %%
d + t2
# Out:
# datetime.datetime(2021, 4, 19, 10, 58, 55)

# %%
d - t2
# Out:
# datetime.datetime(2021, 4, 19, 11, 0, 55)

# %% [markdown]
# ¿Cambios de mes?

# %%
t3 = timedelta(days=1)

# %%
t3 + datetime.date(2021, 2, 28)
# Out:
# datetime.date(2021, 3, 1)

# %% [markdown]
# #### Formatear a string

# %%
s1 = d.strftime("%d/%m/%Y, %H:%M:%S")
# dd/mm/YY H:M:S format
s1
# Out:
# '19/04/2021, 10:59:55'

# %%
s2 = d.strftime("%A %d %B %Y, %X")
# dd/mm/YY H:M:S format
s2
# Out:
# 'Monday 19 April 2021, 10:59:55'

# %% [markdown]
# Referencia completa de formateo de fechas:
#
# https://www.programiz.com/python-programming/datetime/strftime

# %% [markdown]
# ## Datos temporales en Pandas
#
# Pandas implementa su propio sistema de datetimes.
# `pd.to_datetimes` nos permite convertir una `Serie` o un `DataFrame` en una `Serie` de datetimes.

# %%
temp_df.head(3)
# Out:
#    Temperature  Year Month      Country ISO3
# 0     -0.03110  1991   Jan  Afghanistan  AFG
# 1      1.43654  1991   Feb  Afghanistan  AFG
# 2      6.88685  1991   Mar  Afghanistan  AFG

# %%
import numpy as np

dates = temp_df.loc[:, ["Year", "Month"]]
dates["Day"] = np.ones(dates.shape[0])
dates
# Out:
#        Year Month  Day
# 0      1991   Jan  1.0
# 1      1991   Feb  1.0
# 2      1991   Mar  1.0
# 3      1991   Apr  1.0
# 4      1991   May  1.0
# ...     ...   ...  ...
# 59899  2016   Aug  1.0
# 59900  2016   Sep  1.0
# 59901  2016   Oct  1.0
# 59902  2016   Nov  1.0
# 59903  2016   Dec  1.0
#
# [59904 rows x 3 columns]

# %%
pd.to_datetime(["1991", "Jan", "1.0"], yearfirst=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2186         try:
# -> 2187             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2188             # If tzaware, these values represent unix timestamps, so we
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# /tmp/ipykernel_10594/1669576989.py in <module>
# ----> 1 pd.to_datetime(["1991", "Jan", "1.0"], yearfirst=True)
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     910             result = _convert_and_box_cache(arg, cache_array)
#     911         else:
# --> 912             result = convert_listlike(arg, format)
#     913     else:
#     914         result = convert_listlike(np.array([arg]), format)[0]
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399     assert format is None or infer_datetime_format
#     400     utc = tz == "utc"
# --> 401     result, tz_parsed = objects_to_datetime64ns(
#     402         arg,
#     403         dayfirst=dayfirst,
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191             return values.view("i8"), tz_parsed
#    2192         except (ValueError, TypeError):
# -> 2193             raise err
#    2194
#    2195     if tz_parsed is not None:
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2173     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2174     try:
# -> 2175         result, tz_parsed = tslib.array_to_datetime(
#    2176             data.ravel("K"),
#    2177             errors=errors,
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1-01-01 00:00:00

# %% [markdown]
# ### Paréntesis: Función `Map`
#
# Esta función permite hacer un `mapeo` (sustituir un valor por otro) sobre los elementos de una serie.

# %%
dates["Month"] = dates["Month"].map(
    {
        "Jan": 1,
        "Feb": 2,
        "Mar": 3,
        "Apr": 4,
        "May": 5,
        "Jun": 6,
        "Jul": 7,
        "Aug": 8,
        "Sep": 9,
        "Oct": 10,
        "Nov": 11,
        "Dec": 12,
    }
)

# %%
dates
# Out:
#        Year  Month  Day
# 0      1991      1  1.0
# 1      1991      2  1.0
# 2      1991      3  1.0
# 3      1991      4  1.0
# 4      1991      5  1.0
# ...     ...    ...  ...
# 59899  2016      8  1.0
# 59900  2016      9  1.0
# 59901  2016     10  1.0
# 59902  2016     11  1.0
# 59903  2016     12  1.0
#
# [59904 rows x 3 columns]

# %%
parsed_dates = pd.to_datetime(dates, yearfirst=True, infer_datetime_format=True)
parsed_dates
# Out:
# 0       1991-01-01
# 1       1991-02-01
# 2       1991-03-01
# 3       1991-04-01
# 4       1991-05-01
#            ...
# 59899   2016-08-01
# 59900   2016-09-01
# 59901   2016-10-01
# 59902   2016-11-01
# 59903   2016-12-01
# Length: 59904, dtype: datetime64[ns]

# %%
temp_df["dates"] = parsed_dates
temp_df
# Out:
#        Temperature  Year Month      Country ISO3      dates
# 0         -0.03110  1991   Jan  Afghanistan  AFG 1991-01-01
# 1          1.43654  1991   Feb  Afghanistan  AFG 1991-02-01
# 2          6.88685  1991   Mar  Afghanistan  AFG 1991-03-01
# 3         12.93970  1991   Apr  Afghanistan  AFG 1991-04-01
# 4         17.07550  1991   May  Afghanistan  AFG 1991-05-01
# ...            ...   ...   ...          ...  ...        ...
# 59899     26.09480  2016   Aug    Venezuela  VEN 2016-08-01
# 59900     26.22090  2016   Sep    Venezuela  VEN 2016-09-01
# 59901     26.62850  2016   Oct    Venezuela  VEN 2016-10-01
# 59902     26.27680  2016   Nov    Venezuela  VEN 2016-11-01
# 59903     26.12860  2016   Dec    Venezuela  VEN 2016-12-01
#
# [59904 rows x 6 columns]

# %% [markdown]
# ### Valores Inválidos
#
# Puede ocurrir que tengamos algún dato inválido que no podamos transformar a `datetime`.
#
# `pd.to_datetime` ofrece el siguiente parámetro para manejar estos problemas:
#
# `errors{‘ignore’, ‘raise’, ‘coerce’}, default ‘raise’`
#
# - If `raise`, then invalid parsing will raise an exception.
#
# - If `coerce`, then invalid parsing will be set as NaT.
#
# - If `ignore`, then invalid parsing will return the input.
#
#
# **Nota:** NaT = Not a Time

# %%
pd.to_datetime(["2009/07/31", "asd"], errors="coerce")
# Out:
# DatetimeIndex(['2009-07-31', 'NaT'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Indexado
#
# Podemos fijar las fechas como índices y luego indexar por rangos de estas

# %%
temperaturas_por_fecha = temp_df.set_index("dates")
temperaturas_por_fecha
# Out:
#             Temperature  Year Month      Country ISO3
# dates
# 1991-01-01     -0.03110  1991   Jan  Afghanistan  AFG
# 1991-02-01      1.43654  1991   Feb  Afghanistan  AFG
# 1991-03-01      6.88685  1991   Mar  Afghanistan  AFG
# 1991-04-01     12.93970  1991   Apr  Afghanistan  AFG
# 1991-05-01     17.07550  1991   May  Afghanistan  AFG
# ...                 ...   ...   ...          ...  ...
# 2016-08-01     26.09480  2016   Aug    Venezuela  VEN
# 2016-09-01     26.22090  2016   Sep    Venezuela  VEN
# 2016-10-01     26.62850  2016   Oct    Venezuela  VEN
# 2016-11-01     26.27680  2016   Nov    Venezuela  VEN
# 2016-12-01     26.12860  2016   Dec    Venezuela  VEN
#
# [59904 rows x 5 columns]

# %%
# Rango 1995-1-1 al 199-12-1
temperaturas_por_fecha.loc["1995-1-1":"1999-12-1"]
# Out:
#             Temperature  Year Month      Country ISO3
# dates
# 1995-01-01      0.92358  1995   Jan  Afghanistan  AFG
# 1995-02-01      2.96133  1995   Feb  Afghanistan  AFG
# 1995-03-01      6.36893  1995   Mar  Afghanistan  AFG
# 1995-04-01     12.26760  1995   Apr  Afghanistan  AFG
# 1995-05-01     18.11870  1995   May  Afghanistan  AFG
# ...                 ...   ...   ...          ...  ...
# 1999-08-01     24.86170  1999   Aug    Venezuela  VEN
# 1999-09-01     25.33310  1999   Sep    Venezuela  VEN
# 1999-10-01     25.35280  1999   Oct    Venezuela  VEN
# 1999-11-01     25.94590  1999   Nov    Venezuela  VEN
# 1999-12-01     25.39510  1999   Dec    Venezuela  VEN
#
# [11520 rows x 5 columns]

# %% [markdown]
# ### Pandas Timedeltas
#
# En general podemos construir un `pd.Timedelta` con los parámetros:
#
# `weeks, days, hours, minutes, seconds, milliseconds, microseconds, nanoseconds`

# %%
ptd1 = pd.Timedelta(weeks=1)
ptd1
# Out:
# Timedelta('7 days 00:00:00')

# %%
temp_df["dates"] + ptd1
# Out:
# 0       1991-01-08
# 1       1991-02-08
# 2       1991-03-08
# 3       1991-04-08
# 4       1991-05-08
#            ...
# 59899   2016-08-08
# 59900   2016-09-08
# 59901   2016-10-08
# 59902   2016-11-08
# 59903   2016-12-08
# Name: dates, Length: 59904, dtype: datetime64[ns]

# %% [markdown]
# Y podemos también hacer Broadcasting con `datetime.timedeltas`

# %%
temp_df["dates"] + datetime.timedelta(days=5)
# Out:
# 0       1991-01-06
# 1       1991-02-06
# 2       1991-03-06
# 3       1991-04-06
# 4       1991-05-06
#            ...
# 59899   2016-08-06
# 59900   2016-09-06
# 59901   2016-10-06
# 59902   2016-11-06
# 59903   2016-12-06
# Name: dates, Length: 59904, dtype: datetime64[ns]

# %% [markdown]
# ## Datos Categóricos

# %% [markdown]
# Una variable categórica es un tipo de dato que puede tomar un número limitado (y usualmente fijo) de posibles valores.
# Ejemplos de esto: Género, clase social, tipo de sangre, etc...
#
# En general, guardar los datos como categóricos es mucho más eficiente que guardarlos como string. Según la referencia de pandas:
#
# > The memory usage of a Categorical is proportional to the number of categories plus the length of the data. In contrast, an object dtype is a constant times the length of the data.
#
# Como ejemplo, usaremos los continentes a los que pertenece cada país:

# %%
countries_and_continents = pd.read_csv("resources/country-and-continent.csv")
countries_and_continents = countries_and_continents.loc[
    :, ["Continent_Name", "Country_Name"]
]
countries_and_continents
# Out:
#     Continent_Name                                  Country_Name
# 0             Asia              Afghanistan, Islamic Republic of
# 1           Europe                                       Albania
# 2       Antarctica  Antarctica (the territory South of 60 deg S)
# 3           Africa      Algeria, People's Democratic Republic of
# 4          Oceania                                American Samoa
# ..             ...                                           ...
# 257         Africa                                        Zambia
# 258        Oceania                            Disputed Territory
# 259           Asia                Iraq-Saudi Arabia Neutral Zone
# 260           Asia                   United Nations Neutral Zone
# 261           Asia                               Spratly Islands
#
# [262 rows x 2 columns]

# %% [markdown]
# Declaramos una variable como categórica transformando la serie a `category` con `.astype("category")`:

# %%
countries_and_continents["Continent_Name"] = countries_and_continents[
    "Continent_Name"
].astype("category")
countries_and_continents["Continent_Name"]
# Out:
# 0            Asia
# 1          Europe
# 2      Antarctica
# 3          Africa
# 4         Oceania
#           ...
# 257        Africa
# 258       Oceania
# 259          Asia
# 260          Asia
# 261          Asia
# Name: Continent_Name, Length: 262, dtype: category
# Categories (7, object): ['Africa', 'Antarctica', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# %% [markdown]
# Podemos acceder a las categorías con:

# %%
countries_and_continents["Continent_Name"].cat.categories
# Out:
# Index(['Africa', 'Antarctica', 'Asia', 'Europe', 'North America', 'Oceania',
#        'South America'],
#       dtype='object')

# %% [markdown]
# ### Operaciones con categorías

# %% [markdown]
# Podemos renombrar categorías:

# %%
countries_and_continents["Continent_Name"] = countries_and_continents[
    "Continent_Name"
].cat.rename_categories(
    [
        "Africa",
        "Antarctica",
        "Asia",
        "Europe",
        "América del Norte",
        "Oceania",
        "América del Sur",
    ]
)

# %%
countries_and_continents.sample(10)
# Out:
#         Continent_Name                         Country_Name
# 75              Europe                              Finland
# 149             Africa                              Morocco
# 186               Asia  Timor-Leste, Democratic Republic of
# 77              Europe                               France
# 146             Europe                              Moldova
# 198  América del Norte                          Saint Lucia
# 33                Asia                    Myanmar, Union of
# 10     América del Sur        Argentina, Argentine Republic
# 89              Europe                            Gibraltar
# 200  América del Norte            Saint Pierre and Miquelon

# %%
countries_and_continents["Continent_Name"] = countries_and_continents[
    "Continent_Name"
].cat.rename_categories({"Europe": "Europa",})

# %%
countries_and_continents
# Out:
#     Continent_Name                                  Country_Name
# 0             Asia              Afghanistan, Islamic Republic of
# 1           Europa                                       Albania
# 2       Antarctica  Antarctica (the territory South of 60 deg S)
# 3           Africa      Algeria, People's Democratic Republic of
# 4          Oceania                                American Samoa
# ..             ...                                           ...
# 257         Africa                                        Zambia
# 258        Oceania                            Disputed Territory
# 259           Asia                Iraq-Saudi Arabia Neutral Zone
# 260           Asia                   United Nations Neutral Zone
# 261           Asia                               Spratly Islands
#
# [262 rows x 2 columns]

# %% [markdown]
# Se pueden agregar categorías

# %%
countries_and_continents["Continent_Name"].cat.add_categories(["Atlantida"])
# Out:
# 0            Asia
# 1          Europa
# 2      Antarctica
# 3          Africa
# 4         Oceania
#           ...
# 257        Africa
# 258       Oceania
# 259          Asia
# 260          Asia
# 261          Asia
# Name: Continent_Name, Length: 262, dtype: category
# Categories (8, object): ['Africa', 'Antarctica', 'Asia', 'Europa', 'América del Norte', 'Oceania', 'América del Sur', 'Atlantida']

# %% [markdown]
# Como también eliminarlas

# %%
# Remover las no usadas
countries_and_continents["Continent_Name"].cat.remove_unused_categories()
# Out:
# 0            Asia
# 1          Europa
# 2      Antarctica
# 3          Africa
# 4         Oceania
#           ...
# 257        Africa
# 258       Oceania
# 259          Asia
# 260          Asia
# 261          Asia
# Name: Continent_Name, Length: 262, dtype: category
# Categories (7, object): ['Africa', 'Antarctica', 'Asia', 'Europa', 'América del Norte', 'Oceania', 'América del Sur']

# %%
# Como también remover una categoría completa. Esto deja los valores de esa categoría con NaN
countries_and_continents["Continent_Name"].cat.remove_categories(["Europa"])
# Out:
# 0            Asia
# 1             NaN
# 2      Antarctica
# 3          Africa
# 4         Oceania
#           ...
# 257        Africa
# 258       Oceania
# 259          Asia
# 260          Asia
# 261          Asia
# Name: Continent_Name, Length: 262, dtype: category
# Categories (6, object): ['Africa', 'Antarctica', 'Asia', 'América del Norte', 'Oceania', 'América del Sur']

# %% [markdown]
# ### Nota sobre memoria
#
# Como habíamos dicho, es mucho más eficiente guardar variables categóricas que strings.
# Podemos ver esto en el siguiente ejemplo:
#
# #### Usando Strings

# %%
strings = pd.DataFrame(["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"] * 1000000, columns=["var"])
strings
# Out:
#         var
# 0         A
# 1         B
# 2         C
# 3         D
# 4         E
# ...      ..
# 9999995   F
# 9999996   G
# 9999997   H
# 9999998   I
# 9999999   J
#
# [10000000 rows x 1 columns]

# %%
strings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   var     object
# dtypes: object(1)
# memory usage: 76.3+ MB

# %% [markdown]
# #### Usando Categorías

# %%
strings = pd.DataFrame(
    ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"] * 1000000, columns=["var"]
)
strings["var"] = strings["var"].astype("category")
strings
# Out:
#         var
# 0         A
# 1         B
# 2         C
# 3         D
# 4         E
# ...      ..
# 9999995   F
# 9999996   G
# 9999997   H
# 9999998   I
# 9999999   J
#
# [10000000 rows x 1 columns]

# %%
strings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   var     category
# dtypes: category(1)
# memory usage: 9.5 MB

# %% [markdown]
# ### Un pequeño merge con los datos anteriores
#
# Notar que en esta versión se especificó sobre que variables hacer el merge en ambos datasets.

# %%
merged_data_2 = pd.merge(
    bli_df,
    countries_and_continents,
    how="left",
    left_on="Country",
    right_on="Country_Name",
)

merged_data_2.head(3)
# Out:
#      Country  Air pollution  Dwellings without basic facilities  \
# 0  Australia            5.0                                 NaN
# 1    Austria           16.0                                 0.9
# 2    Belgium           15.0                                 1.9
#
#    Educational attainment  Employees working very long hours  Employment rate  \
# 0                    81.0                          12.840000        73.000000
# 1                    85.0                           6.590000        72.000000
# 2                    77.0                           4.703333        63.333333
#
#    Feeling safe walking alone at night  Homicide rate  \
# 0                            64.133333       1.100000
# 1                            80.700000       0.466667
# 2                            70.266667       1.033333
#
#    Household net adjusted disposable income  Household net wealth  ...  \
# 0                                   32759.0              427064.0  ...
# 1                                   33541.0              308325.0  ...
# 2                                   30364.0              386006.0  ...
#
#    Self-reported health  Stakeholder engagement for developing regulations  \
# 0                 87.25                                                2.7
# 1                 70.60                                                1.3
# 2                 73.60                                                2.0
#
#    Student skills  Time devoted to leisure and personal care  Voter turnout  \
# 0           411.2                                  14.350000           91.0
# 1           492.8                                  14.530000           80.0
# 2           503.8                                  15.663333           89.0
#
#    Water quality  Years in education  GPD per capita (2018)  Continent_Name  \
# 0      92.666667           20.966667            57395.91947         Oceania
# 1      92.000000           17.000000            51525.04643          Europa
# 2      83.666667           19.300000            47491.32326          Europa
#
#    Country_Name
# 0     Australia
# 1       Austria
# 2       Belgium
#
# [3 rows x 28 columns]

# %% [markdown]
# ## Ordinales
#
# Son variables categóricas con un orden definido.
#
# Por ejemplo, hagamos una clasificación muy simple del clima a partir de la temperatura media. Para esto, calculemos cuartiles:
#
# > Nota: Los elementos meteorológicos a tomar en cuenta para definir un clima son la temperatura, la presión, el viento, la humedad y la precipitación. Referencias: https://es.wikipedia.org/wiki/Clima

# %%
mean_temp = merged_data_2["Mean temperature"]
mean_temp.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mean temperature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_10594/2233344034.py in <module>
# ----> 1 mean_temp = merged_data_2["Mean temperature"]
#       2 mean_temp.head(3)
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Mean temperature'

# %%
mean_temp.describe()
# Out:
# count    38.000000
# mean     10.241025
# std       6.919106
# min      -5.963874
# 25%       7.221766
# 50%       9.804891
# 75%      12.386380
# max      25.504852
# Name: Mean temperature, dtype: float64

# %%
clima_ordinal = pd.qcut(mean_temp, 4, labels=["Polar", "Frio", "Templado", "Calido"])
clima_ordinal
# Out:
# 0       Calido
# 1        Polar
# 2     Templado
# 3       Calido
# 4        Polar
# 5         Frio
# 6       Calido
# 7          NaN
# 8         Frio
# 9        Polar
# 10       Polar
# 11    Templado
# 12        Frio
# 13      Calido
# 14    Templado
# 15       Polar
# 16        Frio
# 17      Calido
# 18      Calido
# 19    Templado
# 20         NaN
# 21       Polar
# 22        Frio
# 23    Templado
# 24      Calido
# 25    Templado
# 26    Templado
# 27       Polar
# 28         NaN
# 29        Frio
# 30      Calido
# 31       Polar
# 32         NaN
# 33        Frio
# 34      Calido
# 35      Calido
# 36       Polar
# 37       Polar
# 38    Templado
# 39    Templado
# 40        Frio
# 41        Frio
# Name: Mean temperature, dtype: category
# Categories (4, object): ['Polar' < 'Frio' < 'Templado' < 'Calido']

# %% [markdown]
# #### Operaciones sobre Series Categóricas con Orden

# %%
clima_ordinal.value_counts()
# Out:
# Polar       10
# Calido      10
# Frio         9
# Templado     9
# Name: Mean temperature, dtype: int64

# %%
clima_ordinal.min()
# Out:
# 'Polar'

# %%
clima_ordinal.max()
# Out:
# 'Calido'

# %%
clima_ordinal.mode()
# Out:
# 0     Polar
# 1    Calido
# Name: Mean temperature, dtype: category
# Categories (4, object): ['Polar' < 'Frio' < 'Templado' < 'Calido']

# %% [markdown]
# ---
#
# ### Ordenar y Filtrar usando Ordinales

# %%
merged_data_2["Clima cuartiles"] = clima_ordinal
merged_data_2.head(3)
# Out:
#      Country  Air pollution  Dwellings without basic facilities  \
# 0  Australia            5.0                                 NaN
# 1    Austria           16.0                                 0.9
# 2    Belgium           15.0                                 1.9
#
#    Educational attainment  Employees working very long hours  Employment rate  \
# 0                    81.0                          12.840000        73.000000
# 1                    85.0                           6.590000        72.000000
# 2                    77.0                           4.703333        63.333333
#
#    Feeling safe walking alone at night  Homicide rate  \
# 0                            64.133333       1.100000
# 1                            80.700000       0.466667
# 2                            70.266667       1.033333
#
#    Household net adjusted disposable income  Household net wealth  ...  \
# 0                                   32759.0              427064.0  ...
# 1                                   33541.0              308325.0  ...
# 2                                   30364.0              386006.0  ...
#
#    Time devoted to leisure and personal care  Voter turnout  Water quality  \
# 0                                  14.350000           91.0      92.666667
# 1                                  14.530000           80.0      92.000000
# 2                                  15.663333           89.0      83.666667
#
#    Years in education  GPD per capita (2018)  Mean temperature  \
# 0           20.966667            57395.91947         21.966571
# 1           17.000000            51525.04643          7.202215
# 2           19.300000            47491.32326         10.573462
#
#    Count temperature  Continent_Name  Country_Name  Clima cuartiles
# 0              312.0         Oceania     Australia           Calido
# 1              312.0          Europa       Austria            Polar
# 2              312.0          Europa       Belgium         Templado
#
# [3 rows x 31 columns]

# %%
merged_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 4 to 32
# Data columns (total 31 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country                                            42 non-null     object
#  1   Air pollution                                      42 non-null     float64
#  2   Dwellings without basic facilities                 39 non-null     float64
#  3   Educational attainment                             41 non-null     float64
#  4   Employees working very long hours                  40 non-null     float64
#  5   Employment rate                                    42 non-null     float64
#  6   Feeling safe walking alone at night                42 non-null     float64
#  7   Homicide rate                                      42 non-null     float64
#  8   Household net adjusted disposable income           30 non-null     float64
#  9   Household net wealth                               29 non-null     float64
#  10  Housing expenditure                                40 non-null     float64
#  11  Labour market insecurity                           35 non-null     float64
#  12  Life expectancy                                    42 non-null     float64
#  13  Life satisfaction                                  42 non-null     float64
#  14  Long-term unemployment rate                        40 non-null     float64
#  15  Personal earnings                                  36 non-null     float64
#  16  Quality of support network                         42 non-null     float64
#  17  Rooms per person                                   39 non-null     float64
#  18  Self-reported health                               39 non-null     float64
#  19  Stakeholder engagement for developing regulations  40 non-null     float64
#  20  Student skills                                     41 non-null     float64
#  21  Time devoted to leisure and personal care          24 non-null     float64
#  22  Voter turnout                                      42 non-null     float64
#  23  Water quality                                      42 non-null     float64
#  24  Years in education                                 41 non-null     float64
#  25  GPD per capita (2018)                              42 non-null     float64
#  26  Mean temperature                                   38 non-null     float64
#  27  Count temperature                                  38 non-null     float64
#  28  Continent_Name                                     41 non-null     category
#  29  Country_Name                                       41 non-null     object
#  30  Clima cuartiles                                    38 non-null     category
# dtypes: category(2), float64(27), object(2)
# memory usage: 10.5+ KB

# %%
merged_data_2 = merged_data_2.sort_values(["Clima cuartiles", "Mean temperature"])
merged_data_2
# Out:
#             Country  Air pollution  Dwellings without basic facilities  \
# 4            Canada            7.0                                 0.2
# 31           Russia           15.0                                14.8
# 27           Norway            5.0                                 0.0
# 15          Iceland            3.0                                 0.0
# 10          Finland            6.0                                 0.5
# 36           Sweden            6.0                                 0.0
# 9           Estonia            8.0                                 7.0
# 21           Latvia           11.0                                13.9
# 37      Switzerland           15.0                                 0.1
# 1           Austria           16.0                                 0.9
# 22        Lithuania           14.0                                13.6
# 41    United States           10.0                                 0.1
# 5             Chile           16.0                                 9.4
# 29           Poland           22.0                                 3.0
# 8           Denmark            9.0                                 0.5
# 40   United Kingdom           11.0                                 0.3
# 12          Germany           14.0                                 0.2
# 16          Ireland            7.0                                 1.0
# 33         Slovenia           16.0                                 0.4
# 23       Luxembourg           12.0                                 0.5
# 26      New Zealand            5.0                                 NaN
# 25      Netherlands           14.0                                 0.1
# 2           Belgium           15.0                                 1.9
# 14          Hungary           19.0                                 4.7
# 19            Japan           14.0                                 6.4
# 11           France           13.0                                 0.5
# 38           Turkey           20.0                                 8.0
# 39           Turkey           20.0                                 8.0
# 18            Italy           18.0                                 0.7
# 35            Spain           11.0                                 0.1
# 13           Greece           18.0                                 0.5
# 30         Portugal           10.0                                 1.0
# 34     South Africa           22.0                                37.0
# 17           Israel           21.0                                 NaN
# 24           Mexico           16.0                                25.5
# 0         Australia            5.0                                 NaN
# 6          Colombia           10.0                                23.9
# 3            Brazil           10.0                                 6.7
# 7    Czech Republic           20.0                                 0.7
# 20            Korea           28.0                                 2.5
# 28     OECD - Total           14.0                                 4.4
# 32  Slovak Republic           21.0                                 1.2
#
#     Educational attainment  Employees working very long hours  \
# 4                91.333333                           3.673333
# 31               94.000000                           0.140000
# 27               82.000000                           2.886667
# 15               77.000000                          14.866667
# 10               88.000000                           3.816667
# 36               83.000000                           1.066667
# 9                88.666667                           2.436667
# 21               87.666667                           1.280000
# 37               87.666667                           0.370000
# 1                85.000000                           6.590000
# 22               92.666667                           0.546667
# 41               90.666667                          10.990000
# 5                65.000000                           9.316667
# 29               92.000000                           5.823333
# 8                81.000000                           2.316667
# 40               81.000000                          12.123333
# 12               86.666667                           4.196667
# 16               82.000000                           5.260000
# 33               88.000000                           4.333333
# 23               76.666667                           3.740000
# 26               78.666667                          15.036667
# 25               78.333333                           0.413333
# 2                77.000000                           4.703333
# 14               84.000000                           2.976667
# 19                     NaN                                NaN
# 11               78.333333                           7.656667
# 38               39.000000                          31.043333
# 39               39.000000                          31.043333
# 18               61.000000                           4.003333
# 35               59.000000                           3.963333
# 13               73.000000                           6.280000
# 30               47.666667                           8.340000
# 34               73.333333                          17.840000
# 17               87.333333                          15.273333
# 24               37.666667                          27.280000
# 0                81.000000                          12.840000
# 6                54.000000                          26.006667
# 3                49.000000                           7.006667
# 7                93.666667                           5.496667
# 20               87.666667                                NaN
# 28               78.333333                          10.786667
# 32               91.333333                           4.073333
#
#     Employment rate  Feeling safe walking alone at night  Homicide rate  \
# 4         73.333333                            82.500000       1.266667
# 31        70.333333                            53.466667       9.933333
# 27        74.000000                            90.033333       0.400000
# 15        85.666667                            86.300000       0.500000
# 10        70.333333                            85.266667       1.266667
# 36        76.666667                            75.566667       0.900000
# 9         74.000000                            69.633333       3.166667
# 21        70.000000                            63.066667       4.933333
# 37        79.666667                            85.333333       0.600000
# 1         72.000000                            80.700000       0.466667
# 22        70.333333                            56.233333       3.433333
# 41        70.000000                            73.900000       5.500000
# 5         62.666667                            48.000000       4.200000
# 29        66.000000                            67.466667       0.733333
# 8         74.000000                            83.566667       0.600000
# 40        75.000000                            77.766667       0.166667
# 12        75.333333                            72.600000       0.500000
# 16        67.333333                            76.000000       0.666667
# 33        69.333333                            86.166667       0.600000
# 23        66.333333                            75.866667       0.566667
# 26        77.000000                            66.266667       1.300000
# 25        75.666667                            82.066667       0.600000
# 2         63.333333                            70.266667       1.033333
# 14        68.000000                            56.700000       1.000000
# 19        75.000000                            72.800000       0.200000
# 11        65.333333                            70.700000       0.466667
# 38        51.666667                            59.833333       1.366667
# 39        51.666667                            59.833333       1.366667
# 18        58.000000                            58.600000       0.600000
# 35        62.333333                            82.166667       0.600000
# 13        53.333333                            60.200000       0.833333
# 30        68.000000                            73.766667       1.000000
# 34        43.333333                            36.333333      14.000000
# 17        69.000000                            69.966667       1.833333
# 24        61.666667                            41.966667      18.633333
# 0         73.000000                            64.133333       1.100000
# 6         67.000000                            44.566667      25.000000
# 3         61.000000                            35.866667      27.000000
# 7         73.666667                            72.533333       0.500000
# 20        66.666667                            66.666667       1.000000
# 28        68.000000                            68.500000       3.733333
# 32        66.000000                            63.700000       0.800000
#
#     Household net adjusted disposable income  Household net wealth  ...  \
# 4                                    30854.0              423849.0  ...
# 31                                       NaN                   NaN  ...
# 27                                   35725.0              228936.0  ...
# 15                                       NaN                   NaN  ...
# 10                                   29943.0              200827.0  ...
# 36                                   31287.0                   NaN  ...
# 9                                    19697.0              159373.0  ...
# 21                                   16275.0               70160.0  ...
# 37                                   37466.0                   NaN  ...
# 1                                    33541.0              308325.0  ...
# 22                                   21660.0                   NaN  ...
# 41                                   45284.0              632100.0  ...
# 5                                        NaN              100967.0  ...
# 29                                   19814.0              210991.0  ...
# 8                                    29606.0              118637.0  ...
# 40                                   28715.0              548392.0  ...
# 12                                   34294.0              259667.0  ...
# 16                                   25310.0              217130.0  ...
# 33                                   20820.0              203044.0  ...
# 23                                   39264.0              769053.0  ...
# 26                                       NaN              388514.0  ...
# 25                                   29333.0              157824.0  ...
# 2                                    30364.0              386006.0  ...
# 14                                       NaN              104458.0  ...
# 19                                   29798.0              305878.0  ...
# 11                                   31304.0              280653.0  ...
# 38                                       NaN                   NaN  ...
# 39                                       NaN                   NaN  ...
# 18                                   26588.0              279889.0  ...
# 35                                   23999.0              373548.0  ...
# 13                                   17700.0              150134.0  ...
# 30                                   21203.0              232666.0  ...
# 34                                       NaN                   NaN  ...
# 17                                       NaN                   NaN  ...
# 24                                       NaN                   NaN  ...
# 0                                    32759.0              427064.0  ...
# 6                                        NaN                   NaN  ...
# 3                                        NaN                   NaN  ...
# 7                                    21453.0                   NaN  ...
# 20                                   21882.0              285980.0  ...
# 28                                   33604.0              408376.0  ...
# 32                                   20474.0              119696.0  ...
#
#     Time devoted to leisure and personal care  Voter turnout  Water quality  \
# 4                                   14.553333           68.0      91.000000
# 31                                        NaN           68.0      55.333333
# 27                                  15.563333           78.0      97.666667
# 15                                        NaN           79.0      98.666667
# 10                                  15.163333           67.0      95.000000
# 36                                  15.176667           86.0      96.000000
# 9                                   14.886667           64.0      84.000000
# 21                                  13.826667           59.0      79.333333
# 37                                        NaN           49.0      95.333333
# 1                                   14.530000           80.0      92.000000
# 22                                        NaN           51.0      80.666667
# 41                                  14.440000           65.0      82.666667
# 5                                         NaN           47.0      71.000000
# 29                                  14.390000           55.0      82.000000
# 8                                   15.873333           86.0      95.000000
# 40                                  14.916667           69.0      83.666667
# 12                                  15.613333           76.0      91.333333
# 16                                        NaN           65.0      85.000000
# 33                                  14.730000           53.0      89.666667
# 23                                        NaN           91.0      84.000000
# 26                                  14.883333           80.0      89.000000
# 25                                        NaN           82.0      93.000000
# 2                                   15.663333           89.0      83.666667
# 14                                        NaN           70.0      77.000000
# 19                                        NaN           53.0      87.000000
# 11                                  16.336667           75.0      81.000000
# 38                                  14.653333           86.0      65.000000
# 39                                  14.653333           86.0      65.000000
# 18                                  16.313333           73.0      71.000000
# 35                                  15.860000           70.0      72.333333
# 13                                        NaN           64.0      69.333333
# 30                                        NaN           56.0      86.333333
# 34                                  14.770000           73.0      67.000000
# 17                                        NaN           72.0      67.000000
# 24                                        NaN           63.0      67.666667
# 0                                   14.350000           91.0      92.666667
# 6                                         NaN           53.0      74.666667
# 3                                         NaN           79.0      73.000000
# 7                                         NaN           61.0      86.666667
# 20                                  14.583333           77.0      76.000000
# 28                                  14.896667           68.0      81.000000
# 32                                        NaN           60.0      84.666667
#
#     Years in education  GPD per capita (2018)  Mean temperature  \
# 4            17.333333           46313.171370         -5.963874
# 31           16.200000           11584.995380         -5.255763
# 27           18.333333           81734.465570          1.726860
# 15           19.033333           72968.704230          2.307253
# 10           19.833333           50021.291060          2.402188
# 36           19.300000           54589.060390          2.537722
# 9            17.700000           23258.467580          6.166056
# 21           18.033333           17805.280310          6.696891
# 37           17.500000           82818.108160          6.713588
# 1            17.000000           51525.046430          7.202215
# 22           18.400000           19080.617370          7.280419
# 41           17.200000           62996.664820          7.617000
# 5            17.500000           15924.794240          8.454478
# 29           17.666667           15460.644280          8.667610
# 8            19.500000           61390.693010          8.678213
# 40           17.500000           43043.227820          9.062469
# 12           18.100000           47639.003440          9.429345
# 16           18.100000           78621.227960          9.640844
# 33           18.366667           26054.542100          9.677381
# 23           15.100000          116654.261100          9.932402
# 26           17.700000           42949.930580         10.022858
# 25           18.666667           53048.096210         10.316402
# 2            19.300000           47491.323260         10.573462
# 14           16.433333           16150.772760         10.876787
# 19           16.366667           39159.423560         11.338797
# 11           16.500000           41631.090740         11.541326
# 38           18.300000            9370.176355         11.666377
# 39           18.300000            9370.176355         11.666377
# 18           16.600000           34520.085160         12.626380
# 35           17.900000           30337.679130         13.903968
# 13           19.000000           20324.305010         14.304441
# 30           16.933333           23461.571860         15.476961
# 34                 NaN            6374.028196         18.215114
# 17           15.633333           41719.725440         20.264818
# 24           15.166667            9673.443674         21.185824
# 0            20.966667           57395.919470         21.966571
# 6            14.100000            6718.585324         24.734349
# 3            16.166667            9001.234249         25.504852
# 7            17.900000           23046.949130               NaN
# 20           17.266667           33340.265150               NaN
# 28           17.200000           39299.242250               NaN
# 32           15.766667           19428.116210               NaN
#
#     Count temperature     Continent_Name     Country_Name  Clima cuartiles
# 4               312.0  América del Norte           Canada            Polar
# 31              312.0             Europa           Russia            Polar
# 27              312.0             Europa           Norway            Polar
# 15              312.0             Europa          Iceland            Polar
# 10              312.0             Europa          Finland            Polar
# 36              312.0             Europa           Sweden            Polar
# 9               312.0             Europa          Estonia            Polar
# 21              312.0             Europa           Latvia            Polar
# 37              312.0             Europa      Switzerland            Polar
# 1               312.0             Europa          Austria            Polar
# 22              312.0             Europa        Lithuania             Frio
# 41              312.0  América del Norte    United States             Frio
# 5               312.0    América del Sur            Chile             Frio
# 29              312.0             Europa           Poland             Frio
# 8               312.0             Europa          Denmark             Frio
# 40              312.0             Europa   United Kingdom             Frio
# 12              312.0             Europa          Germany             Frio
# 16              312.0             Europa          Ireland             Frio
# 33              312.0             Europa         Slovenia             Frio
# 23              312.0             Europa       Luxembourg         Templado
# 26              312.0            Oceania      New Zealand         Templado
# 25              312.0             Europa      Netherlands         Templado
# 2               312.0             Europa          Belgium         Templado
# 14              312.0             Europa          Hungary         Templado
# 19              312.0               Asia            Japan         Templado
# 11              312.0             Europa           France         Templado
# 38              312.0             Europa           Turkey         Templado
# 39              312.0               Asia           Turkey         Templado
# 18              312.0             Europa            Italy           Calido
# 35              312.0             Europa            Spain           Calido
# 13              312.0             Europa           Greece           Calido
# 30              312.0             Europa         Portugal           Calido
# 34              312.0             Africa     South Africa           Calido
# 17              312.0               Asia           Israel           Calido
# 24              312.0  América del Norte           Mexico           Calido
# 0               312.0            Oceania        Australia           Calido
# 6               312.0    América del Sur         Colombia           Calido
# 3               312.0    América del Sur           Brazil           Calido
# 7                 NaN             Europa   Czech Republic              NaN
# 20                NaN               Asia            Korea              NaN
# 28                NaN                NaN              NaN              NaN
# 32                NaN             Europa  Slovak Republic              NaN
#
# [42 rows x 31 columns]

# %% [markdown]
# ### Paréntesis: Filtrado booleano o Máscaras
#
# Como habíamos visto antes, es una operación que permite filtrar ciertos datos desde un DataFrame usando un arreglo de booleanos. Un poco acerca del origen del termino:
#
# > El término proviene de la capacidad de las máscaras para permitir a través de sus agujeros la visualización de ciertas partes de aquello que cubren, a la vez que ocultan (enmascaran) aquello tapado por las zonas no perforadas.
#
# ![Una máscara](./resources/mask.png)

# %% [markdown]
# ### Nota sobre Merge con id repetidos
#
# > Pregunta: ¿Qué sucede si hacemos un merge de una fila con muchas otras con igual identificador?

# %%
merged_data_2["Clima cuartiles"].cat.categories
# Out:
# Index(['Polar', 'Frio', 'Templado', 'Calido'], dtype='object')

# %%
mask = merged_data_2["Clima cuartiles"] < "Frio"
mask
# Out:
# 4      True
# 31     True
# 27     True
# 15     True
# 10     True
# 36     True
# 9      True
# 21     True
# 37     True
# 1      True
# 22    False
# 41    False
# 5     False
# 29    False
# 8     False
# 40    False
# 12    False
# 16    False
# 33    False
# 23    False
# 26    False
# 25    False
# 2     False
# 14    False
# 19    False
# 11    False
# 38    False
# 39    False
# 18    False
# 35    False
# 13    False
# 30    False
# 34    False
# 17    False
# 24    False
# 0     False
# 6     False
# 3     False
# 7     False
# 20    False
# 28    False
# 32    False
# Name: Clima cuartiles, dtype: bool

# %%
merged_data_2[mask]
# Out:
#         Country  Air pollution  Dwellings without basic facilities  \
# 4        Canada            7.0                                 0.2
# 31       Russia           15.0                                14.8
# 27       Norway            5.0                                 0.0
# 15      Iceland            3.0                                 0.0
# 10      Finland            6.0                                 0.5
# 36       Sweden            6.0                                 0.0
# 9       Estonia            8.0                                 7.0
# 21       Latvia           11.0                                13.9
# 37  Switzerland           15.0                                 0.1
# 1       Austria           16.0                                 0.9
#
#     Educational attainment  Employees working very long hours  \
# 4                91.333333                           3.673333
# 31               94.000000                           0.140000
# 27               82.000000                           2.886667
# 15               77.000000                          14.866667
# 10               88.000000                           3.816667
# 36               83.000000                           1.066667
# 9                88.666667                           2.436667
# 21               87.666667                           1.280000
# 37               87.666667                           0.370000
# 1                85.000000                           6.590000
#
#     Employment rate  Feeling safe walking alone at night  Homicide rate  \
# 4         73.333333                            82.500000       1.266667
# 31        70.333333                            53.466667       9.933333
# 27        74.000000                            90.033333       0.400000
# 15        85.666667                            86.300000       0.500000
# 10        70.333333                            85.266667       1.266667
# 36        76.666667                            75.566667       0.900000
# 9         74.000000                            69.633333       3.166667
# 21        70.000000                            63.066667       4.933333
# 37        79.666667                            85.333333       0.600000
# 1         72.000000                            80.700000       0.466667
#
#     Household net adjusted disposable income  Household net wealth  ...  \
# 4                                    30854.0              423849.0  ...
# 31                                       NaN                   NaN  ...
# 27                                   35725.0              228936.0  ...
# 15                                       NaN                   NaN  ...
# 10                                   29943.0              200827.0  ...
# 36                                   31287.0                   NaN  ...
# 9                                    19697.0              159373.0  ...
# 21                                   16275.0               70160.0  ...
# 37                                   37466.0                   NaN  ...
# 1                                    33541.0              308325.0  ...
#
#     Time devoted to leisure and personal care  Voter turnout  Water quality  \
# 4                                   14.553333           68.0      91.000000
# 31                                        NaN           68.0      55.333333
# 27                                  15.563333           78.0      97.666667
# 15                                        NaN           79.0      98.666667
# 10                                  15.163333           67.0      95.000000
# 36                                  15.176667           86.0      96.000000
# 9                                   14.886667           64.0      84.000000
# 21                                  13.826667           59.0      79.333333
# 37                                        NaN           49.0      95.333333
# 1                                   14.530000           80.0      92.000000
#
#     Years in education  GPD per capita (2018)  Mean temperature  \
# 4            17.333333            46313.17137         -5.963874
# 31           16.200000            11584.99538         -5.255763
# 27           18.333333            81734.46557          1.726860
# 15           19.033333            72968.70423          2.307253
# 10           19.833333            50021.29106          2.402188
# 36           19.300000            54589.06039          2.537722
# 9            17.700000            23258.46758          6.166056
# 21           18.033333            17805.28031          6.696891
# 37           17.500000            82818.10816          6.713588
# 1            17.000000            51525.04643          7.202215
#
#     Count temperature     Continent_Name  Country_Name  Clima cuartiles
# 4               312.0  América del Norte        Canada            Polar
# 31              312.0             Europa        Russia            Polar
# 27              312.0             Europa        Norway            Polar
# 15              312.0             Europa       Iceland            Polar
# 10              312.0             Europa       Finland            Polar
# 36              312.0             Europa        Sweden            Polar
# 9               312.0             Europa       Estonia            Polar
# 21              312.0             Europa        Latvia            Polar
# 37              312.0             Europa   Switzerland            Polar
# 1               312.0             Europa       Austria            Polar
#
# [10 rows x 31 columns]

# %% [markdown]
# ## Anexo: Cómo Combinar dos Filtros/Máscaras Booleanas
#
# Se puede usar las operaciones `|` (or) y `&` and para combinar dos máscaras.

# %%
mask_2 = (merged_data_2["Clima cuartiles"] < "Frio") | (
    merged_data_2["Clima cuartiles"] == "Templado"
)
mask_2
# Out:
# 4      True
# 31     True
# 27     True
# 15     True
# 10     True
# 36     True
# 9      True
# 21     True
# 37     True
# 1      True
# 22    False
# 41    False
# 5     False
# 29    False
# 8     False
# 40    False
# 12    False
# 16    False
# 33    False
# 23     True
# 26     True
# 25     True
# 2      True
# 14     True
# 19     True
# 11     True
# 38     True
# 39     True
# 18    False
# 35    False
# 13    False
# 30    False
# 34    False
# 17    False
# 24    False
# 0     False
# 6     False
# 3     False
# 7     False
# 20    False
# 28    False
# 32    False
# Name: Clima cuartiles, dtype: bool

# %%
merged_data_2[mask_2]
# Out:
#         Country  Air pollution  Dwellings without basic facilities  \
# 4        Canada            7.0                                 0.2
# 31       Russia           15.0                                14.8
# 27       Norway            5.0                                 0.0
# 15      Iceland            3.0                                 0.0
# 10      Finland            6.0                                 0.5
# 36       Sweden            6.0                                 0.0
# 9       Estonia            8.0                                 7.0
# 21       Latvia           11.0                                13.9
# 37  Switzerland           15.0                                 0.1
# 1       Austria           16.0                                 0.9
# 23   Luxembourg           12.0                                 0.5
# 26  New Zealand            5.0                                 NaN
# 25  Netherlands           14.0                                 0.1
# 2       Belgium           15.0                                 1.9
# 14      Hungary           19.0                                 4.7
# 19        Japan           14.0                                 6.4
# 11       France           13.0                                 0.5
# 38       Turkey           20.0                                 8.0
# 39       Turkey           20.0                                 8.0
#
#     Educational attainment  Employees working very long hours  \
# 4                91.333333                           3.673333
# 31               94.000000                           0.140000
# 27               82.000000                           2.886667
# 15               77.000000                          14.866667
# 10               88.000000                           3.816667
# 36               83.000000                           1.066667
# 9                88.666667                           2.436667
# 21               87.666667                           1.280000
# 37               87.666667                           0.370000
# 1                85.000000                           6.590000
# 23               76.666667                           3.740000
# 26               78.666667                          15.036667
# 25               78.333333                           0.413333
# 2                77.000000                           4.703333
# 14               84.000000                           2.976667
# 19                     NaN                                NaN
# 11               78.333333                           7.656667
# 38               39.000000                          31.043333
# 39               39.000000                          31.043333
#
#     Employment rate  Feeling safe walking alone at night  Homicide rate  \
# 4         73.333333                            82.500000       1.266667
# 31        70.333333                            53.466667       9.933333
# 27        74.000000                            90.033333       0.400000
# 15        85.666667                            86.300000       0.500000
# 10        70.333333                            85.266667       1.266667
# 36        76.666667                            75.566667       0.900000
# 9         74.000000                            69.633333       3.166667
# 21        70.000000                            63.066667       4.933333
# 37        79.666667                            85.333333       0.600000
# 1         72.000000                            80.700000       0.466667
# 23        66.333333                            75.866667       0.566667
# 26        77.000000                            66.266667       1.300000
# 25        75.666667                            82.066667       0.600000
# 2         63.333333                            70.266667       1.033333
# 14        68.000000                            56.700000       1.000000
# 19        75.000000                            72.800000       0.200000
# 11        65.333333                            70.700000       0.466667
# 38        51.666667                            59.833333       1.366667
# 39        51.666667                            59.833333       1.366667
#
#     Household net adjusted disposable income  Household net wealth  ...  \
# 4                                    30854.0              423849.0  ...
# 31                                       NaN                   NaN  ...
# 27                                   35725.0              228936.0  ...
# 15                                       NaN                   NaN  ...
# 10                                   29943.0              200827.0  ...
# 36                                   31287.0                   NaN  ...
# 9                                    19697.0              159373.0  ...
# 21                                   16275.0               70160.0  ...
# 37                                   37466.0                   NaN  ...
# 1                                    33541.0              308325.0  ...
# 23                                   39264.0              769053.0  ...
# 26                                       NaN              388514.0  ...
# 25                                   29333.0              157824.0  ...
# 2                                    30364.0              386006.0  ...
# 14                                       NaN              104458.0  ...
# 19                                   29798.0              305878.0  ...
# 11                                   31304.0              280653.0  ...
# 38                                       NaN                   NaN  ...
# 39                                       NaN                   NaN  ...
#
#     Time devoted to leisure and personal care  Voter turnout  Water quality  \
# 4                                   14.553333           68.0      91.000000
# 31                                        NaN           68.0      55.333333
# 27                                  15.563333           78.0      97.666667
# 15                                        NaN           79.0      98.666667
# 10                                  15.163333           67.0      95.000000
# 36                                  15.176667           86.0      96.000000
# 9                                   14.886667           64.0      84.000000
# 21                                  13.826667           59.0      79.333333
# 37                                        NaN           49.0      95.333333
# 1                                   14.530000           80.0      92.000000
# 23                                        NaN           91.0      84.000000
# 26                                  14.883333           80.0      89.000000
# 25                                        NaN           82.0      93.000000
# 2                                   15.663333           89.0      83.666667
# 14                                        NaN           70.0      77.000000
# 19                                        NaN           53.0      87.000000
# 11                                  16.336667           75.0      81.000000
# 38                                  14.653333           86.0      65.000000
# 39                                  14.653333           86.0      65.000000
#
#     Years in education  GPD per capita (2018)  Mean temperature  \
# 4            17.333333           46313.171370         -5.963874
# 31           16.200000           11584.995380         -5.255763
# 27           18.333333           81734.465570          1.726860
# 15           19.033333           72968.704230          2.307253
# 10           19.833333           50021.291060          2.402188
# 36           19.300000           54589.060390          2.537722
# 9            17.700000           23258.467580          6.166056
# 21           18.033333           17805.280310          6.696891
# 37           17.500000           82818.108160          6.713588
# 1            17.000000           51525.046430          7.202215
# 23           15.100000          116654.261100          9.932402
# 26           17.700000           42949.930580         10.022858
# 25           18.666667           53048.096210         10.316402
# 2            19.300000           47491.323260         10.573462
# 14           16.433333           16150.772760         10.876787
# 19           16.366667           39159.423560         11.338797
# 11           16.500000           41631.090740         11.541326
# 38           18.300000            9370.176355         11.666377
# 39           18.300000            9370.176355         11.666377
#
#     Count temperature     Continent_Name  Country_Name  Clima cuartiles
# 4               312.0  América del Norte        Canada            Polar
# 31              312.0             Europa        Russia            Polar
# 27              312.0             Europa        Norway            Polar
# 15              312.0             Europa       Iceland            Polar
# 10              312.0             Europa       Finland            Polar
# 36              312.0             Europa        Sweden            Polar
# 9               312.0             Europa       Estonia            Polar
# 21              312.0             Europa        Latvia            Polar
# 37              312.0             Europa   Switzerland            Polar
# 1               312.0             Europa       Austria            Polar
# 23              312.0             Europa    Luxembourg         Templado
# 26              312.0            Oceania   New Zealand         Templado
# 25              312.0             Europa   Netherlands         Templado
# 2               312.0             Europa       Belgium         Templado
# 14              312.0             Europa       Hungary         Templado
# 19              312.0               Asia         Japan         Templado
# 11              312.0             Europa        France         Templado
# 38              312.0             Europa        Turkey         Templado
# 39              312.0               Asia        Turkey         Templado
#
# [19 rows x 31 columns]
